# %% [markdown]
#  ![Debugging code](project_icon.jpg)
#
# In today’s fast-paced, data-driven world, companies rely heavily on accurate analyses of sales data to make informed decisions. However, the quality of the insights derived from such analyses depend significantly on the integrity of the underlying code.
#
# Your colleague has written some code to automate sales data analyses. The code contains bugs and so does not give accurate analyses of the data. Unfortunately, your colleague is on a business trip and you have been asked to debug some functions in the code. The company plans to use your revised code to improve the accuracy of sales analytics.
#
# Your task is to identify potential edge cases in the functions and the underlying data that might result in logic and runtime errors, such as missing values, incorrect data types, or incompatible values (e.g., negatives). Enhance the custom functions provided by implementing exceptions to catch data quality issues and edge cases.
#
# Your company has provided you with a csv file called "sales_data_sample.csv" for the analyses. This data has 25 columns, but only two columns are analyzed, namely, `quantity_ordered` and `price_each`. A sample of the data is shown below.

# %% [markdown]
# Your task is to identify errors, add exceptions in the get_quantity_ordered_sum() and get_price_each_average() functions for edge cases, and edit sales_df data, outside of the functions, as needed to ensure functions pass. Both functions require adding, inside, the correct exception types that raise errors for edge cases.
#
# - Run theget_quantity_ordered_sum() function with sales_df['quantity_ordered'] as argument. What is the total number of quantities ordered? Store the result as an integer variable called total_quantity_ordered.
# - Identify a potential edge case that might give an incorrect result due to logic or data issues. Modify the function to account for issues, producing the correct output.
# - Run the get_price_each_average() function with sales_df['price_each'] as argument.
# - Observe the traceback and type of exception raised at runtime.
# - Modify the function to effectively work with the data and raise an exception if the data type is invalid.
# - Calculate the average of the price_each column. Store the result as a float variable called average_price_each.

# %%
# Sample code

import pandas as pd

sales_df = pd.read_csv("data/sales_data_sample.csv")
sales_df.head()
# Out:
#    order_number  quantity_ordered  ... contact_first_name  deal_size
# 0         10107                30  ...               Kwai      Small
# 1         10121                34  ...               Paul      Small
# 2         10134               -41  ...             Daniel     Medium
# 3         10145                45  ...              Julie     Medium
# 4         10159                49  ...              Julie     Medium
#
# [5 rows x 25 columns]

# %%
def get_quantity_ordered_sum(sales_quantity_ordered):
    """Calculates the total sum on the 'quantity_ordered' column.

    Args:
        sales_quantity_ordered (pd.core.series.Series): The pandas Series for the 'quantity_ordered' column.

    Returns:
        total_quantity_ordered (int): The total sum of the 'quantity_ordered' column.
    """

    total_quantity_ordered = 0
    for quantity in sales_quantity_ordered:
        total_quantity_ordered += quantity
    return total_quantity_ordered

# %%
def get_price_each_average(sales_price_each, num_places=2):
    """Calculates the average on the 'price_each' column
       using pandas built in methods and rounds to the desired number of places.

    Args:
        sales_price_each (pd.core.series.Series): The pandas Series for the 'price_each' column.
        num_of_places (int): The number of decimal places to round.

    Returns:
        average_price_each (float): The average of the 'price_each' column.
    """

    total_of_price_each = sales_price_each.sum()
    len_of_price_each = len(sales_price_each)
    average_price_each = round(
        total_of_price_each / len_of_price_each, num_places
    )
    return average_price_each

# %%
#  Add as many cells as you require

# %% [markdown]
# # Solution

# %%
import pandas as pd

def get_quantity_ordered_sum(sales_quantity_ordered):
    """Calculates the total sum on the 'quantity_ordered' column.

    Args:
        sales_quantity_ordered (pd.core.series.Series): The pandas Series for the 'quantity_ordered' column.

    Returns:
        total_quantity_ordered (int): The total sum of the 'quantity_ordered' column.
    """
    total_quantity_ordered = 0
    try:
        for quantity in sales_quantity_ordered:
            if quantity < 0:
              	# Convert to absolute value
                quantity *= -1
            total_quantity_ordered += quantity
    except TypeError:
        raise TypeError("Invalid data type in 'quantity_ordered' column.")
    return total_quantity_ordered

    
def get_price_each_average(sales_price_each, num_of_places=2):
    """Calculates the average on the 'price_each' column
       using pandas built in methods and rounds to the desired number of places.

    Args:
        sales_price_each (pd.core.series.Series): The pandas Series for the 'price_each' column.
        num_of_places (int): The number of decimal places to round.

    Returns:
        average_price_each (float): The average of the 'price_each' column.
    """
    try:
        total_of_price_each = sales_price_each.sum()
        len_of_price_each = len(sales_price_each)
        average_price_each = round(
            total_of_price_each / len_of_price_each, num_of_places
        )
    except TypeError:
        sales_price_each = pd.to_numeric(sales_price_each, errors='coerce')
        sales_price_each.fillna(sales_price_each.mean())
        total_of_price_each = sales_price_each.sum()
        len_of_price_each = len(sales_price_each)
        average_price_each = round(
            total_of_price_each / len_of_price_each, num_of_places
        )
    return average_price_each
  
total_quantity_ordered = get_quantity_ordered_sum(sales_df['quantity_ordered'])
average_price_each = get_price_each_average(sales_df['price_each'])
print(total_quantity_ordered)
print(average_price_each)
