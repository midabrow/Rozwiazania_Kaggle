# %% [markdown]
# ![image](image.jpg)
#
# `As a Software Engineer in a Health and Leisure company, your task is to add a new feature to the app: a calorie and nutrition calculator. This tool will calculate and display total calories, sugars, fats, and other nutritional values for different foods based on user input.
#
# You have been provided with the `nutrition.json` dataset, which contains the necessary nutritional information for various foods. Each value in the dataset is per **100 grams** of the food item. The dataset has already been read and loaded for you as the dictionary `nutrition_dict`.
#
# ## Dataset Summary
#
# `nutrition.json`
#
# | Column        | Description                                             |
# |---------------|---------------------------------------------------------|
# | `food` | The name of the food.                                   |
# | `calories`  | The amount of energy provided by the food, measured in kilocalories (kcal) per 100 grams. |
# | `total_fat` | The total fat content in grams per 100 grams.                         |
# | `protein`   | The protein content in grams per 100 grams.                           |
# | `carbohydrate` | The total carbohydrate content in grams per 100 grams.             |
# | `sugars`    | The amount of sugars in grams per 100 grams.                          |
#
# ### Let's Get Started!
#
# This project is a great opportunity to build a real-world feature from scratch, showcasing your development skills and making a meaningful impact on users' health and wellness.`

# %% [markdown]
# Enhance the Diet Coach app by creating the nutritional_summary() function to calculate and return the total nutritional values from the nutrition_dict dataset.
#
# **Function Output:**
#
# - If all the foods are present in the dataset, the function returns a dictionary with keys: "calories", "total_fat", "protein", "carbohydrate", "sugars".
#
# - If any food is missing from the dataset, the function returns the name of the first missing item.
#
# **Input Format:**
#
# - Dictionary: For example, calling nutritional_summary({"Croissants, cheese": 150, "Orange juice, raw": 250}) should output {'calories': 733.5, 'total_fat': 32.0, 'protein': 15.55, 'carbohydrate': 96.5, 'sugars': 38.025} Here, 150 and 250 represent the grams of each food.
#
# - Handling non-existent keys: For example, calling nutritional_summary({"Croissant": 150, "Orange juice": 250}) should output "Croissant".

# %%
import json  # Import the json module to work with JSON files

# Open the nutrition.json file in read mode and load its content into a dictionary
with open('nutrition.json', 'r') as json_file:
    nutrition_dict = json.load(json_file)  # Load the JSON content into a dictionary
    
# Display the first 3 items of the nutrition dictionary
list(nutrition_dict.items())[:3]
# Out:
# [('Cornstarch',
#   {'calories': 381,
#    'total_fat': 0.1,
#    'protein': 0.26,
#    'carbohydrate': 91.27,
#    'sugars': 0.0}),
#  ('Nuts, pecans',
#   {'calories': 691,
#    'total_fat': 72.0,
#    'protein': 9.17,
#    'carbohydrate': 13.86,
#    'sugars': 3.97}),
#  ('Eggplant, raw',
#   {'calories': 25,
#    'total_fat': 0.2,
#    'protein': 0.98,
#    'carbohydrate': 5.88,
#    'sugars': 3.53})]

# %%
nutrition_dict
# Out:
# {'Cornstarch': {'calories': 381,
#   'total_fat': 0.1,
#   'protein': 0.26,
#   'carbohydrate': 91.27,
#   'sugars': 0.0},
#  'Nuts, pecans': {'calories': 691,
#   'total_fat': 72.0,
#   'protein': 9.17,
#   'carbohydrate': 13.86,
#   'sugars': 3.97},
#  'Eggplant, raw': {'calories': 25,
#   'total_fat': 0.2,
#   'protein': 0.98,
#   'carbohydrate': 5.88,
#   'sugars': 3.53},
#  'Teff, uncooked': {'calories': 367,
#   'total_fat': 2.4,
#   'protein': 13.3,
#   'carbohydrate': 73.13,
#   'sugars': 1.84},
#  'Sherbet, orange': {'calories': 144,
#   'total_fat': 2.0,
#   'protein': 1.1,
#   'carbohydrate': 30.4,
#   'sugars': 24.32},
#  'Cauliflower, raw': {'calories': 25,
#   'total_fat': 0.3,
#   'protein': 1.92,
#   'carbohydrate': 4.97,
#   'sugars': 1.91},
#  'Taro leaves, raw': {'calories': 42,
#   'total_fat': 0.7,
#   'protein': 4.98,
#   'carbohydrate': 6.7,
#   'sugars': 3.01},
#  'Lamb, raw, ground': {'calories': 282,
#   'total_fat': 23.0,
#   'protein': 16.56,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  'Cheese, camembert': {'calories': 300,
#   'total_fat': 24.0,
#   'protein': 19.8,
#   'carbohydrate': 0.46,
#   'sugars': 0.46},
#  'Vegetarian fillets': {'calories': 290,
#   'total_fat': 18.0,
#   'protein': 23.0,
#   'carbohydrate': 9.0,
#   'sugars': 0.8},
#  'PACE, Picante Sauce': {'calories': 25,
#   'total_fat': 0.0,
#   'protein': 0.0,
#   'carbohydrate': 6.25,
#   'sugars': 6.25},
#  'Goji berries, dried': {'calories': 349,
#   'total_fat': 0.4,
#   'protein': 14.26,
#   'carbohydrate': 77.06,
#   'sugars': 45.61},
#  'Mango nectar, canned': {'calories': 51,
#   'total_fat': 0.1,
#   'protein': 0.11,
#   'carbohydrate': 13.12,
#   'sugars': 12.45},
#  'Crackers, rusk toast': {'calories': 407,
#   'total_fat': 7.2,
#   'protein': 13.5,
#   'carbohydrate': 72.3,
#   'sugars': 0.0},
#  'Chicken, boiled, feet': {'calories': 215,
#   'total_fat': 15.0,
#   'protein': 19.4,
#   'carbohydrate': 0.2,
#   'sugars': 0.0},
#  'Quail, raw, meat only': {'calories': 134,
#   'total_fat': 4.5,
#   'protein': 21.76,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  'Pie, lemon, fried pies': {'calories': 316,
#   'total_fat': 16.0,
#   'protein': 3.0,
#   'carbohydrate': 42.6,
#   'sugars': 0.0},
#  'Peppers, raw, jalapeno': {'calories': 29,
#   'total_fat': 0.4,
#   'protein': 0.91,
#   'carbohydrate': 6.5,
#   'sugars': 4.12},
#  'Winged bean tuber, raw': {'calories': 148,
#   'total_fat': 0.9,
#   'protein': 11.6,
#   'carbohydrate': 28.1,
#   'sugars': 0.0},
#  'Salami, turkey, cooked': {'calories': 172,
#   'total_fat': 9.2,
#   'protein': 19.2,
#   'carbohydrate': 1.55,
#   'sugars': 1.12},
#  'Grapes, raw, muscadine': {'calories': 57,
#   'total_fat': 0.5,
#   'protein': 0.81,
#   'carbohydrate': 13.93,
#   'sugars': 0.0},
#  'Nuts, raw, ginkgo nuts': {'calories': 182,
#   'total_fat': 1.7,
#   'protein': 4.32,
#   'carbohydrate': 37.6,
#   'sugars': 0.0},
#  'Spices, ground, savory': {'calories': 272,
#   'total_fat': 5.9,
#   'protein': 6.73,
#   'carbohydrate': 68.73,
#   'sugars': 0.0},
#  'Candies, sesame crunch': {'calories': 516,
#   'total_fat': 33.0,
#   'protein': 11.6,
#   'carbohydrate': 50.3,
#   'sugars': 31.17},
#  'Cheese, low fat, cream': {'calories': 201,
#   'total_fat': 15.0,
#   'protein': 7.85,
#   'carbohydrate': 8.13,
#   'sugars': 5.82},
#  'PACE, Green Taco Sauce': {'calories': 25,
#   'total_fat': 0.0,
#   'protein': 0.0,
#   'carbohydrate': 6.25,
#   'sugars': 6.25},
#  'Syrup, Canadian, maple': {'calories': 270,
#   'total_fat': 0.0,
#   'protein': 0.0,
#   'carbohydrate': 67.38,
#   'sugars': 59.92},
#  'Ostrich, raw, top loin': {'calories': 119,
#   'total_fat': 3.0,
#   'protein': 21.67,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  'Chewing gum, sugarless': {'calories': 268,
#   'total_fat': 0.4,
#   'protein': 0.0,
#   'carbohydrate': 94.8,
#   'sugars': 0.0},
#  'Nuts, dried, pine nuts': {'calories': 673,
#   'total_fat': 68.0,
#   'protein': 13.69,
#   'carbohydrate': 13.08,
#   'sugars': 3.59},
#  'Pasta, unenriched, dry': {'calories': 371,
#   'total_fat': 1.5,
#   'protein': 13.04,
#   'carbohydrate': 74.67,
#   'sugars': 2.67},
#  "McDONALD'S, Side Salad": {'calories': 20,
#   'total_fat': 0.2,
#   'protein': 1.03,
#   'carbohydrate': 4.3,
#   'sugars': 2.24},
#  'Cookies, Marie biscuit': {'calories': 406,
#   'total_fat': 11.0,
#   'protein': 7.05,
#   'carbohydrate': 70.54,
#   'sugars': 21.16},
#  'Broccoli, raw, chinese': {'calories': 30,
#   'total_fat': 0.8,
#   'protein': 1.2,
#   'carbohydrate': 4.67,
#   'sugars': 0.88},
#  "McDONALD'S, Hash Brown": {'calories': 271,
#   'total_fat': 16.0,
#   'protein': 2.48,
#   'carbohydrate': 28.56,
#   'sugars': 0.54},
#  'Agave, raw (Southwest)': {'calories': 68,
#   'total_fat': 0.2,
#   'protein': 0.52,
#   'carbohydrate': 16.23,
#   'sugars': 2.58},
#  'Emu, raw, outside drum': {'calories': 103,
#   'total_fat': 0.5,
#   'protein': 23.08,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  'Nuts, dried, beechnuts': {'calories': 576,
#   'total_fat': 50.0,
#   'protein': 6.2,
#   'carbohydrate': 33.5,
#   'sugars': 0.0},
#  'Currants, dried, zante': {'calories': 283,
#   'total_fat': 0.3,
#   'protein': 4.08,
#   'carbohydrate': 74.08,
#   'sugars': 67.28},
#  'Lentils, raw, sprouted': {'calories': 106,
#   'total_fat': 0.6,
#   'protein': 8.96,
#   'carbohydrate': 22.14,
#   'sugars': 0.0},
#  'Gravy, mix, dry, onion': {'calories': 322,
#   'total_fat': 3.0,
#   'protein': 9.0,
#   'carbohydrate': 67.64,
#   'sugars': 0.0},
#  'Pie, fruit, fried pies': {'calories': 316,
#   'total_fat': 16.0,
#   'protein': 3.0,
#   'carbohydrate': 42.6,
#   'sugars': 21.4},
#  'Snacks, cakes, popcorn': {'calories': 384,
#   'total_fat': 3.1,
#   'protein': 9.7,
#   'carbohydrate': 80.1,
#   'sugars': 0.72},
#  'Snack, Mixed Berry Bar': {'calories': 383,
#   'total_fat': 11.0,
#   'protein': 13.16,
#   'carbohydrate': 58.84,
#   'sugars': 26.32},
#  'Fish, raw, sheepshead': {'calories': 108,
#   'total_fat': 2.4,
#   'protein': 20.21,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  'Babyfood, pear, juice': {'calories': 47,
#   'total_fat': 0.0,
#   'protein': 0.0,
#   'carbohydrate': 11.86,
#   'sugars': 7.28},
#  'Brussels sprouts, raw': {'calories': 43,
#   'total_fat': 0.3,
#   'protein': 3.38,
#   'carbohydrate': 8.95,
#   'sugars': 2.2},
#  'Broccoli raab, cooked': {'calories': 33,
#   'total_fat': 0.5,
#   'protein': 3.83,
#   'carbohydrate': 3.12,
#   'sugars': 0.62},
#  'Butter oil, anhydrous': {'calories': 876,
#   'total_fat': 99.0,
#   'protein': 0.28,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  'Chicory, raw, witloof': {'calories': 17,
#   'total_fat': 0.1,
#   'protein': 0.9,
#   'carbohydrate': 4.0,
#   'sugars': 0.0},
#  'KEEBLER, Waffle Cones': {'calories': 424,
#   'total_fat': 5.3,
#   'protein': 6.5,
#   'carbohydrate': 87.7,
#   'sugars': 31.6},
#  'KEEBLER, Waffle Bowls': {'calories': 424,
#   'total_fat': 5.3,
#   'protein': 6.5,
#   'carbohydrate': 87.7,
#   'sugars': 31.6},
#  'Broccoli, raw, leaves': {'calories': 28,
#   'total_fat': 0.4,
#   'protein': 2.98,
#   'carbohydrate': 5.06,
#   'sugars': 1.48},
#  'Durian, raw or frozen': {'calories': 147,
#   'total_fat': 5.3,
#   'protein': 1.47,
#   'carbohydrate': 27.09,
#   'sugars': 0.0},
#  'Tomatoes, raw, orange': {'calories': 16,
#   'total_fat': 0.2,
#   'protein': 1.16,
#   'carbohydrate': 3.18,
#   'sugars': 0.0},
#  'Tomatoes, raw, yellow': {'calories': 15,
#   'total_fat': 0.3,
#   'protein': 0.98,
#   'carbohydrate': 2.98,
#   'sugars': 0.0},
#  'Egg custards, dry mix': {'calories': 410,
#   'total_fat': 6.4,
#   'protein': 6.9,
#   'carbohydrate': 82.8,
#   'sugars': 0.0},
#  'Peanut flour, low fat': {'calories': 428,
#   'total_fat': 22.0,
#   'protein': 33.8,
#   'carbohydrate': 31.27,
#   'sugars': 0.0},
#  'Fish, smoked, haddock': {'calories': 116,
#   'total_fat': 1.0,
#   'protein': 25.23,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  "DENNY'S, french fries": {'calories': 282,
#   'total_fat': 14.0,
#   'protein': 3.41,
#   'carbohydrate': 35.2,
#   'sugars': 0.85},
#  'Ground turkey, cooked': {'calories': 203,
#   'total_fat': 10.0,
#   'protein': 27.37,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  'MURRAY, Vanilla Wafer': {'calories': 461,
#   'total_fat': 17.0,
#   'protein': 4.0,
#   'carbohydrate': 72.9,
#   'sugars': 31.5},
#  "WENDY'S, french fries": {'calories': 301,
#   'total_fat': 14.0,
#   'protein': 3.73,
#   'carbohydrate': 39.73,
#   'sugars': 0.4},
#  'Bread, toasted, wheat': {'calories': 313,
#   'total_fat': 4.3,
#   'protein': 12.96,
#   'carbohydrate': 55.77,
#   'sugars': 6.42},
#  'Danish pastry, cheese': {'calories': 374,
#   'total_fat': 22.0,
#   'protein': 8.0,
#   'carbohydrate': 37.2,
#   'sugars': 6.95},
#  'Nuts, glazed, walnuts': {'calories': 500,
#   'total_fat': 36.0,
#   'protein': 8.28,
#   'carbohydrate': 47.59,
#   'sugars': 32.14},
#  'Spices, garlic powder': {'calories': 331,
#   'total_fat': 0.7,
#   'protein': 16.55,
#   'carbohydrate': 72.73,
#   'sugars': 2.43},
#  'Oil, soybean lecithin': {'calories': 763,
#   'total_fat': 100.0,
#   'protein': 0.0,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  'Egg, fresh, raw, yolk': {'calories': 322,
#   'total_fat': 27.0,
#   'protein': 15.86,
#   'carbohydrate': 3.59,
#   'sugars': 0.56},
#  'Fireweed, raw, leaves': {'calories': 103,
#   'total_fat': 2.8,
#   'protein': 4.71,
#   'carbohydrate': 19.22,
#   'sugars': 0.0},
#  'Beef, pastrami, cured': {'calories': 147,
#   'total_fat': 5.8,
#   'protein': 21.8,
#   'carbohydrate': 0.36,
#   'sugars': 0.1},
#  'Frankfurter, meatless': {'calories': 233,
#   'total_fat': 14.0,
#   'protein': 19.61,
#   'carbohydrate': 7.7,
#   'sugars': 0.0},
#  'Emu, raw, flat fillet': {'calories': 102,
#   'total_fat': 0.7,
#   'protein': 22.25,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  'Emu, raw, inside drum': {'calories': 108,
#   'total_fat': 1.5,
#   'protein': 22.22,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  'Ice creams, chocolate': {'calories': 216,
#   'total_fat': 11.0,
#   'protein': 3.8,
#   'carbohydrate': 28.2,
#   'sugars': 25.36},
#  'Snacks, potato sticks': {'calories': 522,
#   'total_fat': 34.0,
#   'protein': 6.7,
#   'carbohydrate': 53.3,
#   'sugars': 0.22},
#  'USDA Commodity, salsa': {'calories': 36,
#   'total_fat': 0.2,
#   'protein': 1.5,
#   'carbohydrate': 7.0,
#   'sugars': 0.0},
#  'Figs, uncooked, dried': {'calories': 249,
#   'total_fat': 0.9,
#   'protein': 3.3,
#   'carbohydrate': 63.87,
#   'sugars': 47.92},
#  'Game meat, raw, horse': {'calories': 133,
#   'total_fat': 4.6,
#   'protein': 21.39,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  'Syrup, fruit flavored': {'calories': 261,
#   'total_fat': 0.0,
#   'protein': 0.0,
#   'carbohydrate': 65.1,
#   'sugars': 65.0},
#  'Broccoli, raw, stalks': {'calories': 28,
#   'total_fat': 0.4,
#   'protein': 2.98,
#   'carbohydrate': 5.24,
#   'sugars': 0.0},
#  'Cream, cultured, sour': {'calories': 198,
#   'total_fat': 19.0,
#   'protein': 2.44,
#   'carbohydrate': 4.63,
#   'sugars': 3.41},
#  'Gravy, canned, au jus': {'calories': 16,
#   'total_fat': 0.2,
#   'protein': 1.2,
#   'carbohydrate': 2.5,
#   'sugars': 0.0},
#  "McDONALD'S, Hamburger": {'calories': 264,
#   'total_fat': 10.0,
#   'protein': 12.92,
#   'carbohydrate': 30.28,
#   'sugars': 6.03},
#  'Cheese, port de salut': {'calories': 352,
#   'total_fat': 28.0,
#   'protein': 23.78,
#   'carbohydrate': 0.57,
#   'sugars': 0.57},
#  'SILK Original Creamer': {'calories': 100,
#   'total_fat': 6.7,
#   'protein': 0.0,
#   'carbohydrate': 6.67,
#   'sugars': 0.0},
#  'SILK Hazelnut Creamer': {'calories': 133,
#   'total_fat': 6.7,
#   'protein': 0.0,
#   'carbohydrate': 20.0,
#   'sugars': 20.0},
#  'Soup, mix, dry, onion': {'calories': 293,
#   'total_fat': 0.3,
#   'protein': 7.48,
#   'carbohydrate': 65.07,
#   'sugars': 4.65},
#  'Mushrooms, raw, enoki': {'calories': 37,
#   'total_fat': 0.3,
#   'protein': 2.66,
#   'carbohydrate': 7.81,
#   'sugars': 0.22},
#  'Bacon and beef sticks': {'calories': 517,
#   'total_fat': 44.0,
#   'protein': 29.1,
#   'carbohydrate': 0.8,
#   'sugars': 0.8},
#  'Salami, pork, Italian': {'calories': 425,
#   'total_fat': 37.0,
#   'protein': 21.7,
#   'carbohydrate': 1.2,
#   'sugars': 1.2},
#  'Crackers, whole-wheat': {'calories': 427,
#   'total_fat': 14.0,
#   'protein': 10.58,
#   'carbohydrate': 69.55,
#   'sugars': 1.19},
#  'Peanuts, raw, spanish': {'calories': 570,
#   'total_fat': 50.0,
#   'protein': 26.15,
#   'carbohydrate': 15.83,
#   'sugars': 0.0},
#  'Hominy, white, canned': {'calories': 72,
#   'total_fat': 0.9,
#   'protein': 1.48,
#   'carbohydrate': 14.26,
#   'sugars': 1.82},
#  'Game meat, raw, moose': {'calories': 102,
#   'total_fat': 0.7,
#   'protein': 22.24,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  'Pears, red anjou, raw': {'calories': 62,
#   'total_fat': 0.1,
#   'protein': 0.33,
#   'carbohydrate': 14.94,
#   'sugars': 9.54},
#  'Horseradish, prepared': {'calories': 48,
#   'total_fat': 0.7,
#   'protein': 1.18,
#   'carbohydrate': 11.29,
#   'sugars': 7.99},
#  'Fish, raw, butterfish': {'calories': 146,
#   'total_fat': 8.0,
#   'protein': 17.28,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  'Lebanon bologna, beef': {'calories': 172,
#   'total_fat': 10.0,
#   'protein': 19.03,
#   'carbohydrate': 0.44,
#   'sugars': 0.0},
#  'Ham and cheese spread': {'calories': 245,
#   'total_fat': 19.0,
#   'protein': 16.18,
#   'carbohydrate': 2.28,
#   'sugars': 0.0},
#  'TACO BELL, Taco Salad': {'calories': 170,
#   'total_fat': 9.2,
#   'protein': 6.69,
#   'carbohydrate': 15.1,
#   'sugars': 0.0},
#  'Sauce, worcestershire': {'calories': 78,
#   'total_fat': 0.0,
#   'protein': 0.0,
#   'carbohydrate': 19.46,
#   'sugars': 10.03},
#  'Candies, marshmallows': {'calories': 318,
#   'total_fat': 0.2,
#   'protein': 1.8,
#   'carbohydrate': 81.3,
#   'sugars': 57.56},
#  'Hummus, home prepared': {'calories': 177,
#   'total_fat': 8.6,
#   'protein': 4.86,
#   'carbohydrate': 20.12,
#   'sugars': 0.27},
#  'Horned melon (Kiwano)': {'calories': 44,
#   'total_fat': 1.3,
#   'protein': 1.78,
#   'carbohydrate': 7.56,
#   'sugars': 0.0},
#  'Ice cream sundae cone': {'calories': 254,
#   'total_fat': 14.0,
#   'protein': 3.0,
#   'carbohydrate': 28.89,
#   'sugars': 21.26},
#  'Peppers, raw, serrano': {'calories': 32,
#   'total_fat': 0.4,
#   'protein': 1.74,
#   'carbohydrate': 6.7,
#   'sugars': 3.83},
#  'Cabbage, cooked, napa': {'calories': 12,
#   'total_fat': 0.2,
#   'protein': 1.1,
#   'carbohydrate': 2.23,
#   'sugars': 0.0},
#  'Peppers, dried, ancho': {'calories': 281,
#   'total_fat': 8.2,
#   'protein': 11.86,
#   'carbohydrate': 51.42,
#   'sugars': 0.0},
#  'Parsley, freeze-dried': {'calories': 271,
#   'total_fat': 5.2,
#   'protein': 31.3,
#   'carbohydrate': 42.38,
#   'sugars': 0.0},
#  'Spices, black, pepper': {'calories': 251,
#   'total_fat': 3.3,
#   'protein': 10.39,
#   'carbohydrate': 63.95,
#   'sugars': 0.64},
#  'Spices, white, pepper': {'calories': 296,
#   'total_fat': 2.1,
#   'protein': 10.4,
#   'carbohydrate': 68.61,
#   'sugars': 0.0},
#  'Yambean (jicama), raw': {'calories': 38,
#   'total_fat': 0.1,
#   'protein': 0.72,
#   'carbohydrate': 8.82,
#   'sugars': 1.8},
#  'Nuts, dried, pilinuts': {'calories': 719,
#   'total_fat': 80.0,
#   'protein': 10.8,
#   'carbohydrate': 3.98,
#   'sugars': 0.0},
#  'Kiwifruit, raw, green': {'calories': 61,
#   'total_fat': 0.5,
#   'protein': 1.14,
#   'carbohydrate': 14.66,
#   'sugars': 8.99},
#  'Drumstick leaves, raw': {'calories': 64,
#   'total_fat': 1.4,
#   'protein': 9.4,
#   'carbohydrate': 8.28,
#   'sugars': 0.0},
#  'Yautia (tannier), raw': {'calories': 98,
#   'total_fat': 0.4,
#   'protein': 1.46,
#   'carbohydrate': 23.63,
#   'sugars': 0.0},
#  'Candies, butterscotch': {'calories': 391,
#   'total_fat': 3.3,
#   'protein': 0.03,
#   'carbohydrate': 90.4,
#   'sugars': 80.46},
#  'Cucumber, raw, peeled': {'calories': 12,
#   'total_fat': 0.2,
#   'protein': 0.59,
#   'carbohydrate': 2.16,
#   'sugars': 1.38},
#  'Dandelion greens, raw': {'calories': 45,
#   'total_fat': 0.7,
#   'protein': 2.7,
#   'carbohydrate': 9.2,
#   'sugars': 0.71},
#  'Melons, raw, honeydew': {'calories': 36,
#   'total_fat': 0.1,
#   'protein': 0.54,
#   'carbohydrate': 9.09,
#   'sugars': 8.12},
#  'Potato salad with egg': {'calories': 157,
#   'total_fat': 9.4,
#   'protein': 1.96,
#   'carbohydrate': 16.18,
#   'sugars': 4.95},
#  'Mushrooms, raw, white': {'calories': 22,
#   'total_fat': 0.3,
#   'protein': 3.09,
#   'carbohydrate': 3.26,
#   'sugars': 1.98},
#  'Mushrooms, raw, morel': {'calories': 31,
#   'total_fat': 0.6,
#   'protein': 3.12,
#   'carbohydrate': 5.1,
#   'sugars': 0.6},
#  'Cheese, Mexican blend': {'calories': 358,
#   'total_fat': 29.0,
#   'protein': 23.54,
#   'carbohydrate': 1.75,
#   'sugars': 1.23},
#  'Oranges, Florida, raw': {'calories': 46,
#   'total_fat': 0.2,
#   'protein': 0.7,
#   'carbohydrate': 11.54,
#   'sugars': 9.14},
#  'SILK Vanilla, soymilk': {'calories': 41,
#   'total_fat': 1.4,
#   'protein': 2.47,
#   'carbohydrate': 4.12,
#   'sugars': 2.88},
#  'Papaya nectar, canned': {'calories': 57,
#   'total_fat': 0.2,
#   'protein': 0.17,
#   'carbohydrate': 14.51,
#   'sugars': 13.91},
#  'Fiddlehead ferns, raw': {'calories': 34,
#   'total_fat': 0.4,
#   'protein': 4.55,
#   'carbohydrate': 5.54,
#   'sugars': 0.0},
#  'SILK Peach soy yogurt': {'calories': 94,
#   'total_fat': 1.2,
#   'protein': 2.35,
#   'carbohydrate': 18.82,
#   'sugars': 14.71},
#  'SILK Plain soy yogurt': {'calories': 66,
#   'total_fat': 1.8,
#   'protein': 2.64,
#   'carbohydrate': 9.69,
#   'sugars': 5.29},
#  'PACE, Enchilada Sauce': {'calories': 40,
#   'total_fat': 0.0,
#   'protein': 1.67,
#   'carbohydrate': 8.33,
#   'sugars': 6.67},
#  'Yeast extract spread': {'calories': 185,
#   'total_fat': 0.9,
#   'protein': 23.88,
#   'carbohydrate': 20.42,
#   'sugars': 1.6},
#  'Tomatoes, raw, green': {'calories': 23,
#   'total_fat': 0.2,
#   'protein': 1.2,
#   'carbohydrate': 5.1,
#   'sugars': 4.0},
#  'Mollusks, raw, snail': {'calories': 90,
#   'total_fat': 1.4,
#   'protein': 16.1,
#   'carbohydrate': 2.0,
#   'sugars': 0.0},
#  'Emu, raw, fan fillet': {'calories': 103,
#   'total_fat': 0.8,
#   'protein': 22.5,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  'Pasta, enriched, dry': {'calories': 371,
#   'total_fat': 1.5,
#   'protein': 13.04,
#   'carbohydrate': 74.67,
#   'sugars': 2.67},
#  'Cookies, gingersnaps': {'calories': 416,
#   'total_fat': 9.8,
#   'protein': 5.6,
#   'carbohydrate': 76.9,
#   'sugars': 19.92},
#  'Sour cream, fat free': {'calories': 74,
#   'total_fat': 0.0,
#   'protein': 3.1,
#   'carbohydrate': 15.6,
#   'sugars': 0.39},
#  'MURRAY, Honey Graham': {'calories': 445,
#   'total_fat': 13.0,
#   'protein': 5.9,
#   'carbohydrate': 75.7,
#   'sugars': 22.0},
#  'Frankfurter, chicken': {'calories': 223,
#   'total_fat': 16.0,
#   'protein': 15.51,
#   'carbohydrate': 2.74,
#   'sugars': 2.98},
#  'Ham, canned, chopped': {'calories': 239,
#   'total_fat': 19.0,
#   'protein': 16.06,
#   'carbohydrate': 0.26,
#   'sugars': 0.0},
#  'Spices, dried, thyme': {'calories': 276,
#   'total_fat': 7.4,
#   'protein': 9.11,
#   'carbohydrate': 63.94,
#   'sugars': 1.71},
#  'Carrot juice, canned': {'calories': 40,
#   'total_fat': 0.2,
#   'protein': 0.95,
#   'carbohydrate': 9.28,
#   'sugars': 3.91},
#  'Corn, dried (Navajo)': {'calories': 386,
#   'total_fat': 5.2,
#   'protein': 9.88,
#   'carbohydrate': 74.93,
#   'sugars': 5.38},
#  'Pate, truffle flavor': {'calories': 327,
#   'total_fat': 29.0,
#   'protein': 11.2,
#   'carbohydrate': 6.3,
#   'sugars': 0.0},
#  'Fruit butters, apple': {'calories': 173,
#   'total_fat': 0.3,
#   'protein': 0.39,
#   'carbohydrate': 42.47,
#   'sugars': 35.3},
#  'Fast foods, coleslaw': {'calories': 153,
#   'total_fat': 9.9,
#   'protein': 0.95,
#   'carbohydrate': 14.89,
#   'sugars': 12.19},
#  'Salami, beef, cooked': {'calories': 261,
#   'total_fat': 22.0,
#   'protein': 12.6,
#   'carbohydrate': 1.9,
#   'sugars': 1.5},
#  'Spices, chili powder': {'calories': 282,
#   'total_fat': 14.0,
#   'protein': 13.46,
#   'carbohydrate': 49.7,
#   'sugars': 7.19},
#  'Spices, caraway seed': {'calories': 333,
#   'total_fat': 15.0,
#   'protein': 19.77,
#   'carbohydrate': 49.9,
#   'sugars': 0.64},
#  'Spices, dried, basil': {'calories': 233,
#   'total_fat': 4.1,
#   'protein': 22.98,
#   'carbohydrate': 47.75,
#   'sugars': 1.71},
#  'Pickle relish, sweet': {'calories': 130,
#   'total_fat': 0.5,
#   'protein': 0.37,
#   'carbohydrate': 35.06,
#   'sugars': 29.13},
#  'Chives, freeze-dried': {'calories': 311,
#   'total_fat': 3.5,
#   'protein': 21.2,
#   'carbohydrate': 64.29,
#   'sugars': 0.0},
#  'Fish, raw, sablefish': {'calories': 195,
#   'total_fat': 15.0,
#   'protein': 13.41,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  'Crackers, multigrain': {'calories': 482,
#   'total_fat': 20.0,
#   'protein': 7.1,
#   'carbohydrate': 67.6,
#   'sugars': 12.0},
#  'Spices, ground, mace': {'calories': 475,
#   'total_fat': 32.0,
#   'protein': 6.71,
#   'carbohydrate': 50.5,
#   'sugars': 0.0},
#  'Spices, onion powder': {'calories': 341,
#   'total_fat': 1.0,
#   'protein': 10.41,
#   'carbohydrate': 79.12,
#   'sugars': 6.63},
#  'Butter, without salt': {'calories': 717,
#   'total_fat': 81.0,
#   'protein': 0.85,
#   'carbohydrate': 0.06,
#   'sugars': 0.06},
#  'Rice noodles, cooked': {'calories': 108,
#   'total_fat': 0.2,
#   'protein': 1.79,
#   'carbohydrate': 24.01,
#   'sugars': 0.03},
#  'Barley flour or meal': {'calories': 345,
#   'total_fat': 1.6,
#   'protein': 10.5,
#   'carbohydrate': 74.52,
#   'sugars': 0.8},
#  'Sesbania flower, raw': {'calories': 27,
#   'total_fat': 0.0,
#   'protein': 1.28,
#   'carbohydrate': 6.73,
#   'sugars': 0.0},
#  'Garlic bread, frozen': {'calories': 350,
#   'total_fat': 17.0,
#   'protein': 8.36,
#   'carbohydrate': 41.72,
#   'sugars': 3.69},
#  'KFC, Popcorn Chicken': {'calories': 351,
#   'total_fat': 22.0,
#   'protein': 17.67,
#   'carbohydrate': 21.18,
#   'sugars': 0.0},
#  "APPLEBEE'S, coleslaw": {'calories': 120,
#   'total_fat': 7.1,
#   'protein': 0.79,
#   'carbohydrate': 13.17,
#   'sugars': 9.33},
#  'Rolls, sweet, dinner': {'calories': 321,
#   'total_fat': 7.4,
#   'protein': 10.04,
#   'carbohydrate': 53.58,
#   'sugars': 15.38},
#  'Cherries, raw, sweet': {'calories': 63,
#   'total_fat': 0.2,
#   'protein': 1.06,
#   'carbohydrate': 16.01,
#   'sugars': 12.82},
#  'Ostrich, raw, ground': {'calories': 165,
#   'total_fat': 8.7,
#   'protein': 20.22,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  'SILK Coffee, soymilk': {'calories': 62,
#   'total_fat': 1.4,
#   'protein': 2.06,
#   'carbohydrate': 10.29,
#   'sugars': 9.47},
#  'Snacks, banana chips': {'calories': 519,
#   'total_fat': 34.0,
#   'protein': 2.3,
#   'carbohydrate': 58.4,
#   'sugars': 35.34},
#  'Peaches, raw, yellow': {'calories': 39,
#   'total_fat': 0.3,
#   'protein': 0.91,
#   'carbohydrate': 9.54,
#   'sugars': 8.39},
#  'Rolls, wheat, dinner': {'calories': 273,
#   'total_fat': 6.3,
#   'protein': 8.6,
#   'carbohydrate': 46.0,
#   'sugars': 1.63},
#  'Candies, HEATH BITES': {'calories': 530,
#   'total_fat': 30.0,
#   'protein': 3.94,
#   'carbohydrate': 63.39,
#   'sugars': 60.02},
#  'Chicken, raw, ground': {'calories': 143,
#   'total_fat': 8.1,
#   'protein': 17.44,
#   'carbohydrate': 0.04,
#   'sugars': 0.0},
#  'Pears, bartlett, raw': {'calories': 63,
#   'total_fat': 0.2,
#   'protein': 0.39,
#   'carbohydrate': 15.01,
#   'sugars': 9.69},
#  'Toppings, strawberry': {'calories': 254,
#   'total_fat': 0.1,
#   'protein': 0.2,
#   'carbohydrate': 66.3,
#   'sugars': 27.38},
#  'KEEBLER, Sugar Cones': {'calories': 375,
#   'total_fat': 3.7,
#   'protein': 7.3,
#   'carbohydrate': 78.0,
#   'sugars': 26.4},
#  'Seaweed, raw, wakame': {'calories': 45,
#   'total_fat': 0.6,
#   'protein': 3.03,
#   'carbohydrate': 9.14,
#   'sugars': 0.65},
#  'Seaweed, dried, agar': {'calories': 306,
#   'total_fat': 0.3,
#   'protein': 6.21,
#   'carbohydrate': 80.88,
#   'sugars': 2.97},
#  'Bread, cracked-wheat': {'calories': 260,
#   'total_fat': 3.9,
#   'protein': 8.7,
#   'carbohydrate': 49.5,
#   'sugars': 0.0},
#  'Amaranth leaves, raw': {'calories': 23,
#   'total_fat': 0.3,
#   'protein': 2.46,
#   'carbohydrate': 4.02,
#   'sugars': 0.0},
#  'Barley, raw, pearled': {'calories': 352,
#   'total_fat': 1.2,
#   'protein': 9.91,
#   'carbohydrate': 77.72,
#   'sugars': 0.8},
#  'Polish sausage, pork': {'calories': 326,
#   'total_fat': 29.0,
#   'protein': 14.1,
#   'carbohydrate': 1.63,
#   'sugars': 0.0},
#  'Spices, curry powder': {'calories': 325,
#   'total_fat': 14.0,
#   'protein': 14.29,
#   'carbohydrate': 55.83,
#   'sugars': 2.76},
#  'Bacon bits, meatless': {'calories': 476,
#   'total_fat': 26.0,
#   'protein': 32.0,
#   'carbohydrate': 28.6,
#   'sugars': 0.0},
#  'Semolina, unenriched': {'calories': 360,
#   'total_fat': 1.1,
#   'protein': 12.68,
#   'carbohydrate': 72.83,
#   'sugars': 0.0},
#  'Grape leaves, canned': {'calories': 69,
#   'total_fat': 2.0,
#   'protein': 4.27,
#   'carbohydrate': 11.71,
#   'sugars': 0.0},
#  'Spices, ground, sage': {'calories': 315,
#   'total_fat': 13.0,
#   'protein': 10.63,
#   'carbohydrate': 60.73,
#   'sugars': 1.71},
#  'PACE, Red Taco Sauce': {'calories': 50,
#   'total_fat': 0.0,
#   'protein': 0.0,
#   'carbohydrate': 12.5,
#   'sugars': 6.25},
#  "DENNY'S, hash browns": {'calories': 197,
#   'total_fat': 9.0,
#   'protein': 2.49,
#   'carbohydrate': 26.59,
#   'sugars': 1.38},
#  "DENNY'S, onion rings": {'calories': 385,
#   'total_fat': 22.0,
#   'protein': 5.29,
#   'carbohydrate': 41.05,
#   'sugars': 4.76},
#  'Ostrich, raw, oyster': {'calories': 125,
#   'total_fat': 3.7,
#   'protein': 21.55,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  'Oil, corn and canola': {'calories': 884,
#   'total_fat': 100.0,
#   'protein': 0.0,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  'Pumpkin flowers, raw': {'calories': 15,
#   'total_fat': 0.1,
#   'protein': 1.03,
#   'carbohydrate': 3.28,
#   'sugars': 0.0},
#  'Celery flakes, dried': {'calories': 319,
#   'total_fat': 2.1,
#   'protein': 11.3,
#   'carbohydrate': 63.7,
#   'sugars': 35.9},
#  'Crackers, egg, matzo': {'calories': 391,
#   'total_fat': 2.1,
#   'protein': 12.3,
#   'carbohydrate': 78.6,
#   'sugars': 0.0},
#  'Loganberries, frozen': {'calories': 55,
#   'total_fat': 0.3,
#   'protein': 1.52,
#   'carbohydrate': 13.02,
#   'sugars': 7.7},
#  'Tangerine juice, raw': {'calories': 43,
#   'total_fat': 0.2,
#   'protein': 0.5,
#   'carbohydrate': 10.1,
#   'sugars': 9.9},
#  'Soybeans, raw, green': {'calories': 147,
#   'total_fat': 6.8,
#   'protein': 12.95,
#   'carbohydrate': 11.05,
#   'sugars': 0.0},
#  'Soybean, curd cheese': {'calories': 151,
#   'total_fat': 8.1,
#   'protein': 12.5,
#   'carbohydrate': 6.9,
#   'sugars': 1.6},
#  'Game meat, raw, bear': {'calories': 161,
#   'total_fat': 8.3,
#   'protein': 20.1,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  'Game meat, raw, deer': {'calories': 120,
#   'total_fat': 2.4,
#   'protein': 22.96,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  'Oranges, navels, raw': {'calories': 49,
#   'total_fat': 0.2,
#   'protein': 0.91,
#   'carbohydrate': 12.54,
#   'sugars': 8.5},
#  'Tostada shells, corn': {'calories': 474,
#   'total_fat': 23.0,
#   'protein': 6.15,
#   'carbohydrate': 64.43,
#   'sugars': 0.0},
#  'Fish, raw, swordfish': {'calories': 144,
#   'total_fat': 6.7,
#   'protein': 19.66,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  'Taro, raw, tahitian': {'calories': 44,
#   'total_fat': 1.0,
#   'protein': 2.79,
#   'carbohydrate': 6.91,
#   'sugars': 0.0},
#  'Chicory greens, raw': {'calories': 23,
#   'total_fat': 0.3,
#   'protein': 1.7,
#   'carbohydrate': 4.7,
#   'sugars': 0.7},
#  'Hearts of palm, raw': {'calories': 115,
#   'total_fat': 0.2,
#   'protein': 2.7,
#   'carbohydrate': 25.61,
#   'sugars': 17.16},
#  'Chayote, raw, fruit': {'calories': 19,
#   'total_fat': 0.1,
#   'protein': 0.82,
#   'carbohydrate': 4.51,
#   'sugars': 1.66},
#  'Fish, smoked, cisco': {'calories': 177,
#   'total_fat': 12.0,
#   'protein': 16.36,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  'Frankfurter, turkey': {'calories': 223,
#   'total_fat': 17.0,
#   'protein': 12.23,
#   'carbohydrate': 3.81,
#   'sugars': 1.21},
#  'Candies, jellybeans': {'calories': 375,
#   'total_fat': 0.1,
#   'protein': 0.0,
#   'carbohydrate': 93.55,
#   'sugars': 70.0},
#  'Oil, ucuhuba butter': {'calories': 884,
#   'total_fat': 100.0,
#   'protein': 0.0,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  'Soy protein isolate': {'calories': 335,
#   'total_fat': 3.4,
#   'protein': 88.32,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  'Syrups, light, corn': {'calories': 283,
#   'total_fat': 0.2,
#   'protein': 0.0,
#   'carbohydrate': 76.79,
#   'sugars': 76.77},
#  'Fish, raw, milkfish': {'calories': 148,
#   'total_fat': 6.7,
#   'protein': 20.53,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  'Fish, raw, monkfish': {'calories': 76,
#   'total_fat': 1.5,
#   'protein': 14.48,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  "Mother's loaf, pork": {'calories': 282,
#   'total_fat': 22.0,
#   'protein': 12.07,
#   'carbohydrate': 7.53,
#   'sugars': 0.0},
#  'Tapioca, dry, pearl': {'calories': 358,
#   'total_fat': 0.0,
#   'protein': 0.19,
#   'carbohydrate': 88.69,
#   'sugars': 3.35},
#  'Guavas, raw, common': {'calories': 68,
#   'total_fat': 1.0,
#   'protein': 2.55,
#   'carbohydrate': 14.32,
#   'sugars': 8.92},
#  'Spices, celery seed': {'calories': 392,
#   'total_fat': 25.0,
#   'protein': 18.07,
#   'carbohydrate': 41.35,
#   'sugars': 0.67},
#  'Candies, peanut bar': {'calories': 522,
#   'total_fat': 34.0,
#   'protein': 15.5,
#   'carbohydrate': 47.4,
#   'sugars': 42.22},
#  'Bread, toasted, rye': {'calories': 284,
#   'total_fat': 3.6,
#   'protein': 9.4,
#   'carbohydrate': 53.1,
#   'sugars': 4.23},
#  'Oil, apricot kernel': {'calories': 884,
#   'total_fat': 100.0,
#   'protein': 0.0,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  'Candies, YORK BITES': {'calories': 394,
#   'total_fat': 7.3,
#   'protein': 1.78,
#   'carbohydrate': 81.64,
#   'sugars': 75.0},
#  'Meatballs, meatless': {'calories': 197,
#   'total_fat': 9.0,
#   'protein': 21.0,
#   'carbohydrate': 8.0,
#   'sugars': 1.25},
#  'Emu, raw, full rump': {'calories': 112,
#   'total_fat': 1.6,
#   'protein': 22.83,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  'Mustard greens, raw': {'calories': 27,
#   'total_fat': 0.4,
#   'protein': 2.86,
#   'carbohydrate': 4.67,
#   'sugars': 1.32},
#  'Seaweed, raw, laver': {'calories': 35,
#   'total_fat': 0.3,
#   'protein': 5.81,
#   'carbohydrate': 5.11,
#   'sugars': 0.49},
#  'Sweet rolls, cheese': {'calories': 360,
#   'total_fat': 18.0,
#   'protein': 7.1,
#   'carbohydrate': 43.7,
#   'sugars': 0.0},
#  'Figs, stewed, dried': {'calories': 107,
#   'total_fat': 0.4,
#   'protein': 1.42,
#   'carbohydrate': 27.57,
#   'sugars': 23.35},
#  'Bread sticks, plain': {'calories': 412,
#   'total_fat': 9.5,
#   'protein': 12.0,
#   'carbohydrate': 68.4,
#   'sugars': 1.26},
#  'SILK Mocha, soymilk': {'calories': 58,
#   'total_fat': 1.4,
#   'protein': 2.06,
#   'carbohydrate': 9.05,
#   'sugars': 7.41},
#  'Milk and cereal bar': {'calories': 413,
#   'total_fat': 11.0,
#   'protein': 6.47,
#   'carbohydrate': 72.05,
#   'sugars': 45.97},
#  'Bread, pumpernickel': {'calories': 250,
#   'total_fat': 3.1,
#   'protein': 8.7,
#   'carbohydrate': 47.5,
#   'sugars': 0.53},
#  'Game meat, raw, elk': {'calories': 111,
#   'total_fat': 1.5,
#   'protein': 22.95,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  'PACE, Pico De Gallo': {'calories': 31,
#   'total_fat': 0.0,
#   'protein': 0.0,
#   'carbohydrate': 9.38,
#   'sugars': 6.25},
#  'Ostrich, raw, round': {'calories': 116,
#   'total_fat': 2.4,
#   'protein': 21.99,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  'HORMEL, Cure 81 Ham': {'calories': 106,
#   'total_fat': 3.6,
#   'protein': 18.43,
#   'carbohydrate': 0.21,
#   'sugars': 0.0},
#  'Prune juice, canned': {'calories': 71,
#   'total_fat': 0.0,
#   'protein': 0.61,
#   'carbohydrate': 17.45,
#   'sugars': 16.45},
#  "McDONALD'S, BIG MAC": {'calories': 257,
#   'total_fat': 15.0,
#   'protein': 11.82,
#   'carbohydrate': 20.08,
#   'sugars': 3.97},
#  'Soy flour, defatted': {'calories': 327,
#   'total_fat': 1.2,
#   'protein': 51.46,
#   'carbohydrate': 33.92,
#   'sugars': 16.42},
#  'Bread, toasted, egg': {'calories': 315,
#   'total_fat': 6.6,
#   'protein': 10.5,
#   'carbohydrate': 52.6,
#   'sugars': 1.94},
#  'Fish, raw, mahimahi': {'calories': 85,
#   'total_fat': 0.7,
#   'protein': 18.5,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  'Fish, raw, bluefish': {'calories': 124,
#   'total_fat': 4.2,
#   'protein': 20.04,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  'Spices, fennel seed': {'calories': 345,
#   'total_fat': 15.0,
#   'protein': 15.8,
#   'carbohydrate': 52.29,
#   'sugars': 0.0},
#  'Potatoes, skin, raw': {'calories': 58,
#   'total_fat': 0.1,
#   'protein': 2.57,
#   'carbohydrate': 12.44,
#   'sugars': 0.0},
#  'Pepper, raw, banana': {'calories': 27,
#   'total_fat': 0.5,
#   'protein': 1.66,
#   'carbohydrate': 5.35,
#   'sugars': 1.95},
#  'Drumstick pods, raw': {'calories': 37,
#   'total_fat': 0.2,
#   'protein': 2.1,
#   'carbohydrate': 8.53,
#   'sugars': 0.0},
#  'Toppings, pineapple': {'calories': 253,
#   'total_fat': 0.1,
#   'protein': 0.1,
#   'carbohydrate': 66.4,
#   'sugars': 21.01},
#  'Acorn stew (Apache)': {'calories': 95,
#   'total_fat': 3.5,
#   'protein': 6.81,
#   'carbohydrate': 9.22,
#   'sugars': 0.34},
#  'Tomatoes, sun-dried': {'calories': 258,
#   'total_fat': 3.0,
#   'protein': 14.11,
#   'carbohydrate': 55.76,
#   'sugars': 37.59},
#  'Guava sauce, cooked': {'calories': 36,
#   'total_fat': 0.1,
#   'protein': 0.32,
#   'carbohydrate': 9.48,
#   'sugars': 5.88},
#  'Pumpkin leaves, raw': {'calories': 19,
#   'total_fat': 0.4,
#   'protein': 3.15,
#   'carbohydrate': 2.33,
#   'sugars': 0.0},
#  'Melons, raw, casaba': {'calories': 28,
#   'total_fat': 0.1,
#   'protein': 1.11,
#   'carbohydrate': 6.58,
#   'sugars': 5.69},
#  'Melon balls, frozen': {'calories': 33,
#   'total_fat': 0.3,
#   'protein': 0.84,
#   'carbohydrate': 7.94,
#   'sugars': 0.0},
#  'Fish oil, cod liver': {'calories': 902,
#   'total_fat': 100.0,
#   'protein': 0.0,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  'Nuts, dried, acorns': {'calories': 509,
#   'total_fat': 31.0,
#   'protein': 8.1,
#   'carbohydrate': 53.66,
#   'sugars': 0.0},
#  'Rolls, pumpernickel': {'calories': 276,
#   'total_fat': 2.8,
#   'protein': 10.8,
#   'carbohydrate': 51.87,
#   'sugars': 0.4},
#  'Gravy, dry, chicken': {'calories': 381,
#   'total_fat': 9.7,
#   'protein': 11.27,
#   'carbohydrate': 62.09,
#   'sugars': 0.0},
#  'Fish, raw, tilefish': {'calories': 96,
#   'total_fat': 2.3,
#   'protein': 17.5,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  'Ice creams, vanilla': {'calories': 207,
#   'total_fat': 11.0,
#   'protein': 3.5,
#   'carbohydrate': 23.6,
#   'sugars': 21.22},
#  'SILK Plain, soymilk': {'calories': 41,
#   'total_fat': 1.7,
#   'protein': 2.88,
#   'carbohydrate': 3.29,
#   'sugars': 2.47},
#  'Cabbage, raw, savoy': {'calories': 27,
#   'total_fat': 0.1,
#   'protein': 2.0,
#   'carbohydrate': 6.1,
#   'sugars': 2.27},
#  'Fish, raw, tilapia': {'calories': 96,
#   'total_fat': 1.7,
#   'protein': 20.08,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  'Broccoli raab, raw': {'calories': 22,
#   'total_fat': 0.5,
#   'protein': 3.17,
#   'carbohydrate': 2.85,
#   'sugars': 0.38},
#  'Corn grain, yellow': {'calories': 365,
#   'total_fat': 4.7,
#   'protein': 9.42,
#   'carbohydrate': 74.26,
#   'sugars': 0.64},
#  'Turtle, raw, green': {'calories': 89,
#   'total_fat': 0.5,
#   'protein': 19.8,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  'Chicory roots, raw': {'calories': 72,
#   'total_fat': 0.2,
#   'protein': 1.4,
#   'carbohydrate': 17.51,
#   'sugars': 8.73},
#  'Ice cream sandwich': {'calories': 237,
#   'total_fat': 8.6,
#   'protein': 4.29,
#   'carbohydrate': 37.14,
#   'sugars': 18.57},
#  'Croutons, seasoned': {'calories': 465,
#   'total_fat': 18.0,
#   'protein': 10.8,
#   'carbohydrate': 63.5,
#   'sugars': 4.41},
#  'Snacks, taro chips': {'calories': 498,
#   'total_fat': 25.0,
#   'protein': 2.3,
#   'carbohydrate': 68.1,
#   'sugars': 3.82},
#  'Prickly pears, raw': {'calories': 41,
#   'total_fat': 0.5,
#   'protein': 0.73,
#   'carbohydrate': 9.57,
#   'sugars': 0.0},
#  'Fish, raw, haddock': {'calories': 74,
#   'total_fat': 0.5,
#   'protein': 16.32,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  'Liver cheese, pork': {'calories': 304,
#   'total_fat': 26.0,
#   'protein': 15.2,
#   'carbohydrate': 2.1,
#   'sugars': 0.0},
#  'Ground turkey, raw': {'calories': 148,
#   'total_fat': 7.7,
#   'protein': 19.66,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  'Jams and preserves': {'calories': 278,
#   'total_fat': 0.1,
#   'protein': 0.37,
#   'carbohydrate': 68.86,
#   'sugars': 48.5},
#  'Carrots, raw, baby': {'calories': 35,
#   'total_fat': 0.1,
#   'protein': 0.64,
#   'carbohydrate': 8.24,
#   'sugars': 4.76},
#  'Oil, nutmeg butter': {'calories': 884,
#   'total_fat': 100.0,
#   'protein': 0.0,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  'Semolina, enriched': {'calories': 360,
#   'total_fat': 1.1,
#   'protein': 12.68,
#   'carbohydrate': 72.83,
#   'sugars': 0.0},
#  'Spices, anise seed': {'calories': 337,
#   'total_fat': 16.0,
#   'protein': 17.6,
#   'carbohydrate': 50.02,
#   'sugars': 0.0},
#  'Snacks, corn cakes': {'calories': 387,
#   'total_fat': 2.4,
#   'protein': 8.1,
#   'carbohydrate': 83.4,
#   'sugars': 23.47},
#  'Catsup, low sodium': {'calories': 101,
#   'total_fat': 0.1,
#   'protein': 1.04,
#   'carbohydrate': 27.4,
#   'sugars': 21.27},
#  'Croissants, cheese': {'calories': 414,
#   'total_fat': 21.0,
#   'protein': 9.2,
#   'carbohydrate': 47.0,
#   'sugars': 11.35},
#  'Milk, fluid, sheep': {'calories': 108,
#   'total_fat': 7.0,
#   'protein': 5.98,
#   'carbohydrate': 5.36,
#   'sugars': 0.0},
#  'Acerola juice, raw': {'calories': 23,
#   'total_fat': 0.3,
#   'protein': 0.4,
#   'carbohydrate': 4.8,
#   'sugars': 4.5},
#  'Jute, raw, potherb': {'calories': 34,
#   'total_fat': 0.3,
#   'protein': 4.65,
#   'carbohydrate': 5.8,
#   'sugars': 0.0},
#  'Fast food, biscuit': {'calories': 370,
#   'total_fat': 19.0,
#   'protein': 7.08,
#   'carbohydrate': 42.82,
#   'sugars': 3.88},
#  'Bagels, multigrain': {'calories': 241,
#   'total_fat': 1.2,
#   'protein': 9.9,
#   'carbohydrate': 47.47,
#   'sugars': 8.66},
#  'Beef, dried, cured': {'calories': 153,
#   'total_fat': 1.9,
#   'protein': 31.1,
#   'carbohydrate': 2.76,
#   'sugars': 2.7},
#  'Nuts, almond paste': {'calories': 458,
#   'total_fat': 28.0,
#   'protein': 9.0,
#   'carbohydrate': 47.81,
#   'sugars': 36.25},
#  'Seaweed, raw, kelp': {'calories': 43,
#   'total_fat': 0.6,
#   'protein': 1.68,
#   'carbohydrate': 9.57,
#   'sugars': 0.6},
#  'Seaweed, raw, agar': {'calories': 26,
#   'total_fat': 0.0,
#   'protein': 0.54,
#   'carbohydrate': 6.75,
#   'sugars': 0.28},
#  'Fish oil, menhaden': {'calories': 902,
#   'total_fat': 100.0,
#   'protein': 0.0,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  'Rolls, egg, dinner': {'calories': 307,
#   'total_fat': 6.4,
#   'protein': 9.5,
#   'carbohydrate': 52.0,
#   'sugars': 4.3},
#  'Bread, white wheat': {'calories': 238,
#   'total_fat': 2.2,
#   'protein': 10.66,
#   'carbohydrate': 43.91,
#   'sugars': 5.0},
#  'Onions, raw, sweet': {'calories': 32,
#   'total_fat': 0.1,
#   'protein': 0.8,
#   'carbohydrate': 7.55,
#   'sugars': 5.02},
#  'Onions, raw, welsh': {'calories': 34,
#   'total_fat': 0.4,
#   'protein': 1.9,
#   'carbohydrate': 6.5,
#   'sugars': 2.18},
#  'SILK Chai, soymilk': {'calories': 53,
#   'total_fat': 1.4,
#   'protein': 2.47,
#   'carbohydrate': 7.82,
#   'sugars': 5.76},
#  'Rolls, rye, dinner': {'calories': 286,
#   'total_fat': 3.4,
#   'protein': 10.3,
#   'carbohydrate': 53.1,
#   'sugars': 1.17},
#  'Gravy, dry, au jus': {'calories': 313,
#   'total_fat': 9.6,
#   'protein': 9.2,
#   'carbohydrate': 47.49,
#   'sugars': 0.0},
#  'Cheese, neufchatel': {'calories': 253,
#   'total_fat': 23.0,
#   'protein': 9.15,
#   'carbohydrate': 3.59,
#   'sugars': 3.19},
#  'Hummus, commercial': {'calories': 166,
#   'total_fat': 9.6,
#   'protein': 7.9,
#   'carbohydrate': 14.29,
#   'sugars': 0.0},
#  'Croissants, butter': {'calories': 406,
#   'total_fat': 21.0,
#   'protein': 8.2,
#   'carbohydrate': 45.8,
#   'sugars': 11.26},
#  'Carrot, dehydrated': {'calories': 341,
#   'total_fat': 1.5,
#   'protein': 8.1,
#   'carbohydrate': 79.57,
#   'sugars': 38.82},
#  'Vinegar, distilled': {'calories': 18,
#   'total_fat': 0.0,
#   'protein': 0.0,
#   'carbohydrate': 0.04,
#   'sugars': 0.04},
#  'Sapote, raw, mamey': {'calories': 124,
#   'total_fat': 0.5,
#   'protein': 1.45,
#   'carbohydrate': 32.1,
#   'sugars': 20.14},
#  'Soy flour, low-fat': {'calories': 372,
#   'total_fat': 8.9,
#   'protein': 49.81,
#   'carbohydrate': 30.63,
#   'sugars': 9.33},
#  'Syrups, sugar free': {'calories': 52,
#   'total_fat': 0.0,
#   'protein': 0.8,
#   'carbohydrate': 12.13,
#   'sugars': 0.01},
#  'Syrups, dark, corn': {'calories': 286,
#   'total_fat': 0.0,
#   'protein': 0.0,
#   'carbohydrate': 77.59,
#   'sugars': 77.59},
#  'Taco shells, baked': {'calories': 476,
#   'total_fat': 22.0,
#   'protein': 6.41,
#   'carbohydrate': 63.49,
#   'sugars': 1.5},
#  'Spices, cumin seed': {'calories': 375,
#   'total_fat': 22.0,
#   'protein': 17.81,
#   'carbohydrate': 44.24,
#   'sugars': 2.25},
#  'Bamboo shoots, raw': {'calories': 27,
#   'total_fat': 0.3,
#   'protein': 2.6,
#   'carbohydrate': 5.2,
#   'sugars': 3.0},
#  'Fish, raw, lingcod': {'calories': 85,
#   'total_fat': 1.1,
#   'protein': 17.66,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  'Whey, dried, sweet': {'calories': 353,
#   'total_fat': 1.1,
#   'protein': 12.93,
#   'carbohydrate': 74.46,
#   'sugars': 74.46},
#  'Whey, fluid, sweet': {'calories': 27,
#   'total_fat': 0.4,
#   'protein': 0.85,
#   'carbohydrate': 5.14,
#   'sugars': 5.14},
#  'Spices, poppy seed': {'calories': 525,
#   'total_fat': 42.0,
#   'protein': 17.99,
#   'carbohydrate': 28.13,
#   'sugars': 2.99},
#  'Babyfood, pretzels': {'calories': 397,
#   'total_fat': 2.0,
#   'protein': 10.8,
#   'carbohydrate': 82.2,
#   'sugars': 3.08},
#  'Fat, mutton tallow': {'calories': 902,
#   'total_fat': 100.0,
#   'protein': 0.0,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  'Coffeecake, cheese': {'calories': 339,
#   'total_fat': 15.0,
#   'protein': 7.0,
#   'carbohydrate': 44.3,
#   'sugars': 0.0},
#  'Sauce, horseradish': {'calories': 503,
#   'total_fat': 51.0,
#   'protein': 1.09,
#   'carbohydrate': 10.05,
#   'sugars': 8.98},
#  'Yardlong bean, raw': {'calories': 47,
#   'total_fat': 0.4,
#   'protein': 2.8,
#   'carbohydrate': 8.35,
#   'sugars': 0.0},
#  'Cress, raw, garden': {'calories': 32,
#   'total_fat': 0.7,
#   'protein': 2.6,
#   'carbohydrate': 5.5,
#   'sugars': 4.4},
#  'Dates, deglet noor': {'calories': 282,
#   'total_fat': 0.4,
#   'protein': 2.45,
#   'carbohydrate': 75.03,
#   'sugars': 63.35},
#  'Lambsquarters, raw': {'calories': 43,
#   'total_fat': 0.8,
#   'protein': 4.2,
#   'carbohydrate': 7.3,
#   'sugars': 0.0},
#  'Gravy, dry, turkey': {'calories': 367,
#   'total_fat': 7.2,
#   'protein': 10.42,
#   'carbohydrate': 65.12,
#   'sugars': 0.0},
#  'Vital wheat gluten': {'calories': 370,
#   'total_fat': 1.9,
#   'protein': 75.16,
#   'carbohydrate': 13.79,
#   'sugars': 0.0},
#  'Turnip greens, raw': {'calories': 32,
#   'total_fat': 0.3,
#   'protein': 1.5,
#   'carbohydrate': 7.13,
#   'sugars': 0.81},
#  'Sugars, granulated': {'calories': 387,
#   'total_fat': 0.0,
#   'protein': 0.0,
#   'carbohydrate': 99.98,
#   'sugars': 99.8},
#  'Frankfurter, pork': {'calories': 269,
#   'total_fat': 24.0,
#   'protein': 12.81,
#   'carbohydrate': 0.28,
#   'sugars': 0.0},
#  'Pomegranates, raw': {'calories': 83,
#   'total_fat': 1.2,
#   'protein': 1.67,
#   'carbohydrate': 18.7,
#   'sugars': 13.67},
#  'Pears, raw, asian': {'calories': 42,
#   'total_fat': 0.2,
#   'protein': 0.5,
#   'carbohydrate': 10.65,
#   'sugars': 7.05},
#  'Cookies, molasses': {'calories': 430,
#   'total_fat': 13.0,
#   'protein': 5.6,
#   'carbohydrate': 73.8,
#   'sugars': 17.6},
#  'Cookies, fig bars': {'calories': 348,
#   'total_fat': 7.3,
#   'protein': 3.7,
#   'carbohydrate': 70.9,
#   'sugars': 46.36},
#  'Liverwurst spread': {'calories': 305,
#   'total_fat': 25.0,
#   'protein': 12.38,
#   'carbohydrate': 5.89,
#   'sugars': 1.65},
#  'Roast beef spread': {'calories': 223,
#   'total_fat': 16.0,
#   'protein': 15.27,
#   'carbohydrate': 3.73,
#   'sugars': 0.71},
#  'Chard, raw, swiss': {'calories': 19,
#   'total_fat': 0.2,
#   'protein': 1.8,
#   'carbohydrate': 3.74,
#   'sugars': 1.1},
#  'Goose, raw, liver': {'calories': 133,
#   'total_fat': 4.3,
#   'protein': 16.37,
#   'carbohydrate': 6.32,
#   'sugars': 0.0},
#  'TACO BELL, Nachos': {'calories': 350,
#   'total_fat': 22.0,
#   'protein': 4.32,
#   'carbohydrate': 34.91,
#   'sugars': 2.17},
#  'Sausage, meatless': {'calories': 255,
#   'total_fat': 18.0,
#   'protein': 20.28,
#   'carbohydrate': 8.09,
#   'sugars': 0.0},
#  'Frankfurter, meat': {'calories': 290,
#   'total_fat': 26.0,
#   'protein': 10.26,
#   'carbohydrate': 4.17,
#   'sugars': 0.0},
#  'Rice flour, brown': {'calories': 363,
#   'total_fat': 2.8,
#   'protein': 7.23,
#   'carbohydrate': 76.48,
#   'sugars': 0.66},
#  'Peppermint, fresh': {'calories': 70,
#   'total_fat': 0.9,
#   'protein': 3.75,
#   'carbohydrate': 14.89,
#   'sugars': 0.0},
#  'Vinegar, red wine': {'calories': 19,
#   'total_fat': 0.0,
#   'protein': 0.04,
#   'carbohydrate': 0.27,
#   'sugars': 0.0},
#  'Vinegar, balsamic': {'calories': 88,
#   'total_fat': 0.0,
#   'protein': 0.49,
#   'carbohydrate': 17.03,
#   'sugars': 14.95},
#  'Luxury loaf, pork': {'calories': 141,
#   'total_fat': 4.8,
#   'protein': 18.4,
#   'carbohydrate': 4.9,
#   'sugars': 0.0},
#  'Rye flour, medium': {'calories': 349,
#   'total_fat': 1.5,
#   'protein': 10.88,
#   'carbohydrate': 75.43,
#   'sugars': 1.1},
#  "DENNY'S, coleslaw": {'calories': 183,
#   'total_fat': 15.0,
#   'protein': 0.97,
#   'carbohydrate': 10.88,
#   'sugars': 8.16},
#  'Bread, wheat bran': {'calories': 248,
#   'total_fat': 3.4,
#   'protein': 8.8,
#   'carbohydrate': 47.8,
#   'sugars': 9.68},
#  'Croissants, apple': {'calories': 254,
#   'total_fat': 8.7,
#   'protein': 7.4,
#   'carbohydrate': 37.1,
#   'sugars': 0.0},
#  'Candies, Tamarind': {'calories': 368,
#   'total_fat': 0.0,
#   'protein': 0.0,
#   'carbohydrate': 91.96,
#   'sugars': 78.57},
#  'Oheloberries, raw': {'calories': 28,
#   'total_fat': 0.2,
#   'protein': 0.38,
#   'carbohydrate': 6.84,
#   'sugars': 0.0},
#  'PACE, Salsa Verde': {'calories': 47,
#   'total_fat': 1.6,
#   'protein': 0.0,
#   'carbohydrate': 6.25,
#   'sugars': 6.25},
#  'Barley malt flour': {'calories': 361,
#   'total_fat': 1.8,
#   'protein': 10.28,
#   'carbohydrate': 78.3,
#   'sugars': 0.8},
#  'Rice noodles, dry': {'calories': 364,
#   'total_fat': 0.6,
#   'protein': 5.95,
#   'carbohydrate': 80.18,
#   'sugars': 0.12},
#  'Fish oil, sardine': {'calories': 902,
#   'total_fat': 100.0,
#   'protein': 0.0,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  'Fish oil, herring': {'calories': 902,
#   'total_fat': 100.0,
#   'protein': 0.0,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  'Plantains, cooked': {'calories': 116,
#   'total_fat': 0.2,
#   'protein': 0.79,
#   'carbohydrate': 31.15,
#   'sugars': 14.0},
#  'Burdock root, raw': {'calories': 72,
#   'total_fat': 0.2,
#   'protein': 1.53,
#   'carbohydrate': 17.34,
#   'sugars': 2.9},
#  'Butterbur, canned': {'calories': 3,
#   'total_fat': 0.1,
#   'protein': 0.11,
#   'carbohydrate': 0.38,
#   'sugars': 0.0},
#  'Ostrich, raw, fan': {'calories': 117,
#   'total_fat': 2.7,
#   'protein': 21.81,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  'SILK Nog, soymilk': {'calories': 74,
#   'total_fat': 1.6,
#   'protein': 2.46,
#   'carbohydrate': 12.3,
#   'sugars': 9.84},
#  'Gravy, dry, brown': {'calories': 367,
#   'total_fat': 9.6,
#   'protein': 10.74,
#   'carbohydrate': 59.38,
#   'sugars': 0.0},
#  'Cheese, provolone': {'calories': 351,
#   'total_fat': 27.0,
#   'protein': 25.58,
#   'carbohydrate': 2.14,
#   'sugars': 0.56},
#  'Cheese, roquefort': {'calories': 369,
#   'total_fat': 31.0,
#   'protein': 21.54,
#   'carbohydrate': 2.0,
#   'sugars': 0.0},
#  'Muffins, oat bran': {'calories': 270,
#   'total_fat': 7.4,
#   'protein': 7.0,
#   'carbohydrate': 48.3,
#   'sugars': 8.22},
#  'Syrups, grenadine': {'calories': 268,
#   'total_fat': 0.0,
#   'protein': 0.0,
#   'carbohydrate': 66.91,
#   'sugars': 46.55},
#  'Raisins, seedless': {'calories': 299,
#   'total_fat': 0.5,
#   'protein': 3.07,
#   'carbohydrate': 79.18,
#   'sugars': 59.19},
#  'Strawberries, raw': {'calories': 32,
#   'total_fat': 0.3,
#   'protein': 0.67,
#   'carbohydrate': 7.68,
#   'sugars': 4.89},
#  'Fish, raw, burbot': {'calories': 90,
#   'total_fat': 0.8,
#   'protein': 19.31,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  'Wheat germ, crude': {'calories': 360,
#   'total_fat': 9.7,
#   'protein': 23.15,
#   'carbohydrate': 51.8,
#   'sugars': 0.0},
#  'Wheat, hard white': {'calories': 342,
#   'total_fat': 1.7,
#   'protein': 11.31,
#   'carbohydrate': 75.9,
#   'sugars': 0.41},
#  'Wheat bran, crude': {'calories': 216,
#   'total_fat': 4.3,
#   'protein': 15.55,
#   'carbohydrate': 64.51,
#   'sugars': 0.41},
#  'Gooseberries, raw': {'calories': 44,
#   'total_fat': 0.6,
#   'protein': 0.88,
#   'carbohydrate': 10.18,
#   'sugars': 0.0},
#  'Spices, dill seed': {'calories': 305,
#   'total_fat': 15.0,
#   'protein': 15.98,
#   'carbohydrate': 55.17,
#   'sugars': 0.0},
#  'Oil, cocoa butter': {'calories': 884,
#   'total_fat': 100.0,
#   'protein': 0.0,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  "APPLEBEE'S, chili": {'calories': 157,
#   'total_fat': 9.8,
#   'protein': 12.56,
#   'carbohydrate': 4.57,
#   'sugars': 2.27},
#  'Grape leaves, raw': {'calories': 93,
#   'total_fat': 2.1,
#   'protein': 5.6,
#   'carbohydrate': 17.31,
#   'sugars': 6.3},
#  'Kale, raw, scotch': {'calories': 42,
#   'total_fat': 0.6,
#   'protein': 2.8,
#   'carbohydrate': 8.32,
#   'sugars': 0.0},
#  'Marmalade, orange': {'calories': 246,
#   'total_fat': 0.0,
#   'protein': 0.3,
#   'carbohydrate': 66.3,
#   'sugars': 60.0},
#  'Whey, dried, acid': {'calories': 339,
#   'total_fat': 0.5,
#   'protein': 11.73,
#   'carbohydrate': 73.45,
#   'sugars': 73.45},
#  'Whey, fluid, acid': {'calories': 24,
#   'total_fat': 0.1,
#   'protein': 0.76,
#   'carbohydrate': 5.12,
#   'sugars': 5.12},
#  'Eggplant, pickled': {'calories': 49,
#   'total_fat': 0.7,
#   'protein': 0.9,
#   'carbohydrate': 9.77,
#   'sugars': 4.8},
#  'Babyfood, cookies': {'calories': 433,
#   'total_fat': 13.0,
#   'protein': 11.8,
#   'carbohydrate': 67.1,
#   'sugars': 24.2},
#  'Fennel, raw, bulb': {'calories': 31,
#   'total_fat': 0.2,
#   'protein': 1.24,
#   'carbohydrate': 7.3,
#   'sugars': 3.93},
#  'Egg, dried, whole': {'calories': 592,
#   'total_fat': 44.0,
#   'protein': 48.05,
#   'carbohydrate': 1.13,
#   'sugars': 0.56},
#  'Coffeecake, fruit': {'calories': 311,
#   'total_fat': 10.0,
#   'protein': 5.2,
# ...
#   'sugars': 0.0},
#  'Yogurt, nonfat, plain, Greek': {'calories': 59,
#   'total_fat': 0.4,
#   'protein': 10.19,
#   'carbohydrate': 3.6,
#   'sugars': 3.24},
#  'Crackers, reduced fat, wheat': {'calories': 444,
#   'total_fat': 13.0,
#   'protein': 9.34,
#   'carbohydrate': 71.52,
#   'sugars': 15.01},
#  'Gravy, powder, dry, mushroom': {'calories': 328,
#   'total_fat': 4.0,
#   'protein': 10.0,
#   'carbohydrate': 64.66,
#   'sugars': 3.26},
#  'Gravy, dry, unspecified type': {'calories': 344,
#   'total_fat': 8.0,
#   'protein': 13.0,
#   'carbohydrate': 58.0,
#   'sugars': 0.0},
#  'Seeds, low-fat, sesame flour': {'calories': 333,
#   'total_fat': 1.8,
#   'protein': 50.14,
#   'carbohydrate': 35.51,
#   'sugars': 0.0},
#  'Mushrooms, microwaved, white': {'calories': 35,
#   'total_fat': 0.5,
#   'protein': 3.91,
#   'carbohydrate': 6.04,
#   'sugars': 0.0},
#  'Beverages, AMP, Energy drink': {'calories': 46,
#   'total_fat': 0.1,
#   'protein': 0.25,
#   'carbohydrate': 12.08,
#   'sugars': 12.08},
#  'SILK Black Cherry soy yogurt': {'calories': 88,
#   'total_fat': 1.2,
#   'protein': 2.35,
#   'carbohydrate': 17.06,
#   'sugars': 11.76},
#  'Snack, original bar, BALANCE': {'calories': 415,
#   'total_fat': 12.0,
#   'protein': 28.0,
#   'carbohydrate': 48.73,
#   'sugars': 34.89},
#  'Beverages, well, tap, water': {'calories': 0,
#   'total_fat': 0.0,
#   'protein': 0.0,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  'Chrysanthemum, raw, garland': {'calories': 24,
#   'total_fat': 0.6,
#   'protein': 3.36,
#   'carbohydrate': 3.02,
#   'sugars': 0.0},
#  'Stew, moose (Alaska Native)': {'calories': 55,
#   'total_fat': 0.5,
#   'protein': 6.6,
#   'carbohydrate': 6.0,
#   'sugars': 0.0},
#  'Ice creams, rich, chocolate': {'calories': 251,
#   'total_fat': 17.0,
#   'protein': 4.72,
#   'carbohydrate': 19.78,
#   'sugars': 17.35},
#  'Oil, walrus (Alaska Native)': {'calories': 900,
#   'total_fat': 100.0,
#   'protein': 0.0,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  'Grapefruit juice, raw, pink': {'calories': 39,
#   'total_fat': 0.1,
#   'protein': 0.5,
#   'carbohydrate': 9.2,
#   'sugars': 0.0},
#  'Babyfood, junior, ham, meat': {'calories': 97,
#   'total_fat': 3.8,
#   'protein': 11.3,
#   'carbohydrate': 3.7,
#   'sugars': 0.0},
#  'Radish seeds, raw, sprouted': {'calories': 43,
#   'total_fat': 2.5,
#   'protein': 3.81,
#   'carbohydrate': 3.6,
#   'sugars': 0.0},
#  'MORI-NU, firm, silken, Tofu': {'calories': 62,
#   'total_fat': 2.7,
#   'protein': 6.9,
#   'carbohydrate': 2.4,
#   'sugars': 1.27},
#  'MORI-NU, soft, silken, Tofu': {'calories': 55,
#   'total_fat': 2.7,
#   'protein': 4.8,
#   'carbohydrate': 2.9,
#   'sugars': 1.31},
#  'Bread, rye, reduced-calorie': {'calories': 203,
#   'total_fat': 2.9,
#   'protein': 9.1,
#   'carbohydrate': 40.5,
#   'sugars': 2.29},
#  'Snacks, air-popped, popcorn': {'calories': 387,
#   'total_fat': 4.5,
#   'protein': 12.94,
#   'carbohydrate': 77.78,
#   'sugars': 0.87},
#  'Muffins, dry mix, blueberry': {'calories': 293,
#   'total_fat': 3.3,
#   'protein': 3.48,
#   'carbohydrate': 61.0,
#   'sugars': 32.73},
#  'Frankfurter, unheated, beef': {'calories': 316,
#   'total_fat': 28.0,
#   'protein': 11.16,
#   'carbohydrate': 3.36,
#   'sugars': 1.31},
#  'Turkey, raw, giblets, whole': {'calories': 124,
#   'total_fat': 5.1,
#   'protein': 18.18,
#   'carbohydrate': 0.07,
#   'sugars': 0.0},
#  'Corn pudding, home prepared': {'calories': 131,
#   'total_fat': 5.0,
#   'protein': 4.42,
#   'carbohydrate': 16.97,
#   'sugars': 6.59},
#  'Popovers, enriched, dry mix': {'calories': 371,
#   'total_fat': 4.3,
#   'protein': 10.4,
#   'carbohydrate': 71.0,
#   'sugars': 0.0},
#  'Soybeans, raw, mature seeds': {'calories': 446,
#   'total_fat': 20.0,
#   'protein': 36.49,
#   'carbohydrate': 30.16,
#   'sugars': 7.33},
#  'Beef sausage, cooked, fresh': {'calories': 332,
#   'total_fat': 28.0,
#   'protein': 18.21,
#   'carbohydrate': 0.35,
#   'sugars': 0.0},
#  'Luncheon meat, canned, pork': {'calories': 334,
#   'total_fat': 30.0,
#   'protein': 12.5,
#   'carbohydrate': 2.1,
#   'sugars': 0.0},
#  'MURRAY, Vanilla Sugar Wafer': {'calories': 527,
#   'total_fat': 26.0,
#   'protein': 3.9,
#   'carbohydrate': 70.0,
#   'sugars': 41.0},
#  'Radishes, raw, white icicle': {'calories': 14,
#   'total_fat': 0.1,
#   'protein': 1.1,
#   'carbohydrate': 2.63,
#   'sugars': 0.0},
#  'Vinespinach, raw, (basella)': {'calories': 19,
#   'total_fat': 0.3,
#   'protein': 1.8,
#   'carbohydrate': 3.4,
#   'sugars': 0.0},
#  'Syrups, high-fructose, corn': {'calories': 281,
#   'total_fat': 0.0,
#   'protein': 0.0,
#   'carbohydrate': 76.0,
#   'sugars': 75.65},
#  'Stew, steamed corn (Navajo)': {'calories': 112,
#   'total_fat': 3.8,
#   'protein': 8.82,
#   'carbohydrate': 10.8,
#   'sugars': 0.51},
#  'OSCAR MAYER, Bologna (beef)': {'calories': 316,
#   'total_fat': 29.0,
#   'protein': 11.05,
#   'carbohydrate': 2.45,
#   'sugars': 1.4},
#  'Ostrich, raw, outside strip': {'calories': 120,
#   'total_fat': 2.2,
#   'protein': 23.36,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  'Milk, fluid, indian buffalo': {'calories': 97,
#   'total_fat': 6.9,
#   'protein': 3.75,
#   'carbohydrate': 5.18,
#   'sugars': 0.0},
#  'Nuts, dried, black, walnuts': {'calories': 619,
#   'total_fat': 59.0,
#   'protein': 24.06,
#   'carbohydrate': 9.58,
#   'sugars': 1.1},
#  'ON THE BORDER, Mexican rice': {'calories': 195,
#   'total_fat': 4.9,
#   'protein': 3.56,
#   'carbohydrate': 34.15,
#   'sugars': 1.38},
#  'Mushrooms, raw, Chanterelle': {'calories': 38,
#   'total_fat': 0.5,
#   'protein': 1.49,
#   'carbohydrate': 6.86,
#   'sugars': 1.16},
#  "McDONALD'S, Baked Apple Pie": {'calories': 323,
#   'total_fat': 16.0,
#   'protein': 3.07,
#   'carbohydrate': 43.62,
#   'sugars': 17.25},
#  "McDONALD'S, Sausage Biscuit": {'calories': 376,
#   'total_fat': 25.0,
#   'protein': 9.62,
#   'carbohydrate': 27.2,
#   'sugars': 1.97},
#  'CHICK-FIL-A, Chick-n-Strips': {'calories': 228,
#   'total_fat': 11.0,
#   'protein': 21.4,
#   'carbohydrate': 10.39,
#   'sugars': 1.24},
#  'Edamame, unprepared, frozen': {'calories': 109,
#   'total_fat': 4.7,
#   'protein': 11.22,
#   'carbohydrate': 7.61,
#   'sugars': 2.48},
#  'Mollusks, raw, blue, mussel': {'calories': 86,
#   'total_fat': 2.2,
#   'protein': 11.9,
#   'carbohydrate': 3.69,
#   'sugars': 0.0},
#  'Quail, total edible, cooked': {'calories': 227,
#   'total_fat': 14.0,
#   'protein': 25.1,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  'Cereals, dry, CREAM OF RICE': {'calories': 370,
#   'total_fat': 0.5,
#   'protein': 6.3,
#   'carbohydrate': 82.4,
#   'sugars': 0.3},
#  'LEAN POCKETS, Ham N Cheddar': {'calories': 230,
#   'total_fat': 6.5,
#   'protein': 10.28,
#   'carbohydrate': 32.52,
#   'sugars': 7.6},
#  'Snacks, tropical, trail mix': {'calories': 442,
#   'total_fat': 17.0,
#   'protein': 6.3,
#   'carbohydrate': 65.6,
#   'sugars': 0.0},
#  'Nuts, full fat, acorn flour': {'calories': 501,
#   'total_fat': 30.0,
#   'protein': 7.49,
#   'carbohydrate': 54.65,
#   'sugars': 0.0},
#  'Sauce, ready-to-serve, fish': {'calories': 35,
#   'total_fat': 0.0,
#   'protein': 5.06,
#   'carbohydrate': 3.64,
#   'sugars': 3.64},
#  'Fish, raw, european, turbot': {'calories': 95,
#   'total_fat': 3.0,
#   'protein': 16.05,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  'Fast foods, caramel, sundae': {'calories': 196,
#   'total_fat': 6.0,
#   'protein': 4.71,
#   'carbohydrate': 31.81,
#   'sugars': 0.0},
#  'Pie fillings, canned, apple': {'calories': 100,
#   'total_fat': 0.1,
#   'protein': 0.1,
#   'carbohydrate': 26.1,
#   'sugars': 13.8},
#  'Sauce, ready-to-serve, plum': {'calories': 184,
#   'total_fat': 1.0,
#   'protein': 0.89,
#   'carbohydrate': 42.81,
#   'sugars': 0.0},
#  'Ostrich, cooked, inside leg': {'calories': 141,
#   'total_fat': 1.9,
#   'protein': 29.01,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  "Gravy, mushroom, CAMPBELL'S": {'calories': 34,
#   'total_fat': 1.7,
#   'protein': 0.0,
#   'carbohydrate': 5.08,
#   'sugars': 1.69},
#  'Snacks, smoked, beef sticks': {'calories': 550,
#   'total_fat': 50.0,
#   'protein': 21.5,
#   'carbohydrate': 5.4,
#   'sugars': 0.0},
#  'Cheese, whole milk, ricotta': {'calories': 174,
#   'total_fat': 13.0,
#   'protein': 11.26,
#   'carbohydrate': 3.04,
#   'sugars': 0.27},
#  'SILK French Vanilla Creamer': {'calories': 133,
#   'total_fat': 6.7,
#   'protein': 0.0,
#   'carbohydrate': 20.0,
#   'sugars': 20.0},
#  'Bread, canned, boston brown': {'calories': 195,
#   'total_fat': 1.5,
#   'protein': 5.2,
#   'carbohydrate': 43.3,
#   'sugars': 2.42},
#  'Cheese, queso blanco, white': {'calories': 310,
#   'total_fat': 24.0,
#   'protein': 20.38,
#   'carbohydrate': 2.53,
#   'sugars': 1.76},
#  'Cheese, queso fresco, fresh': {'calories': 299,
#   'total_fat': 24.0,
#   'protein': 18.09,
#   'carbohydrate': 2.98,
#   'sugars': 2.32},
#  'Beverages, powder, Lemonade': {'calories': 376,
#   'total_fat': 1.1,
#   'protein': 0.0,
#   'carbohydrate': 97.57,
#   'sugars': 94.7},
#  'Apricots, sweetened, frozen': {'calories': 98,
#   'total_fat': 0.1,
#   'protein': 0.7,
#   'carbohydrate': 25.1,
#   'sugars': 0.0},
#  'Muffins, toaster-type, corn': {'calories': 346,
#   'total_fat': 11.0,
#   'protein': 5.3,
#   'carbohydrate': 57.9,
#   'sugars': 0.0},
#  'Tomatoes, cooked, ripe, red': {'calories': 18,
#   'total_fat': 0.1,
#   'protein': 0.95,
#   'carbohydrate': 4.01,
#   'sugars': 2.49},
#  'Squash, raw, baby, zucchini': {'calories': 21,
#   'total_fat': 0.4,
#   'protein': 2.71,
#   'carbohydrate': 3.11,
#   'sugars': 0.0},
#  'HORMEL Canadian Style Bacon': {'calories': 122,
#   'total_fat': 4.9,
#   'protein': 16.88,
#   'carbohydrate': 1.87,
#   'sugars': 1.43},
#  "McDONALD'S, QUARTER POUNDER": {'calories': 244,
#   'total_fat': 12.0,
#   'protein': 14.1,
#   'carbohydrate': 22.17,
#   'sugars': 5.13},
#  'Brotwurst, link, beef, pork': {'calories': 323,
#   'total_fat': 28.0,
#   'protein': 14.3,
#   'carbohydrate': 2.98,
#   'sugars': 2.98},
#  'Pork, cooked, ground, fresh': {'calories': 297,
#   'total_fat': 21.0,
#   'protein': 25.69,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  'Sausage, raw, pork, Italian': {'calories': 346,
#   'total_fat': 31.0,
#   'protein': 14.25,
#   'carbohydrate': 0.65,
#   'sugars': 0.0},
#  'Ham and cheese loaf or roll': {'calories': 241,
#   'total_fat': 19.0,
#   'protein': 13.6,
#   'carbohydrate': 4.0,
#   'sugars': 0.0},
#  'CRACKER BARREL, steak fries': {'calories': 255,
#   'total_fat': 13.0,
#   'protein': 3.26,
#   'carbohydrate': 30.87,
#   'sugars': 0.86},
#  "McDONALD'S, Sausage Burrito": {'calories': 277,
#   'total_fat': 16.0,
#   'protein': 11.1,
#   'carbohydrate': 22.97,
#   'sugars': 2.57},
#  'Candies, CHUNKY Bar, NESTLE': {'calories': 475,
#   'total_fat': 28.0,
#   'protein': 7.5,
#   'carbohydrate': 60.0,
#   'sugars': 52.5},
#  'Fish, raw, freshwater, drum': {'calories': 119,
#   'total_fat': 4.9,
#   'protein': 17.54,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  'Pate, canned, chicken liver': {'calories': 201,
#   'total_fat': 13.0,
#   'protein': 13.45,
#   'carbohydrate': 6.55,
#   'sugars': 0.0},
#  'BURGER KING, Chicken Strips': {'calories': 292,
#   'total_fat': 15.0,
#   'protein': 18.2,
#   'carbohydrate': 20.49,
#   'sugars': 0.0},
#  'Pork, raw, salt pork, cured': {'calories': 748,
#   'total_fat': 81.0,
#   'protein': 5.05,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  'Cereals ready-to-eat, ALPEN': {'calories': 352,
#   'total_fat': 3.3,
#   'protein': 11.2,
#   'carbohydrate': 75.7,
#   'sugars': 20.0},
#  'Light ice cream, Creamsicle': {'calories': 165,
#   'total_fat': 3.1,
#   'protein': 1.54,
#   'carbohydrate': 32.75,
#   'sugars': 18.46},
#  'Toppings, marshmallow cream': {'calories': 322,
#   'total_fat': 0.3,
#   'protein': 0.8,
#   'carbohydrate': 79.0,
#   'sugars': 46.8},
#  'Fish, raw, Pacific, herring': {'calories': 195,
#   'total_fat': 14.0,
#   'protein': 16.39,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  'Sandwich spread, beef, pork': {'calories': 235,
#   'total_fat': 17.0,
#   'protein': 7.66,
#   'carbohydrate': 11.94,
#   'sugars': 0.0},
#  'Nuts, hazelnuts or filberts': {'calories': 628,
#   'total_fat': 61.0,
#   'protein': 14.95,
#   'carbohydrate': 16.7,
#   'sugars': 4.34},
#  'Babyfood, teething biscuits': {'calories': 392,
#   'total_fat': 4.2,
#   'protein': 10.7,
#   'carbohydrate': 76.4,
#   'sugars': 12.65},
#  'PACE, Organic Picante Sauce': {'calories': 25,
#   'total_fat': 0.0,
#   'protein': 0.0,
#   'carbohydrate': 6.25,
#   'sugars': 6.25},
#  'Peppers, raw, yellow, sweet': {'calories': 27,
#   'total_fat': 0.2,
#   'protein': 1.0,
#   'carbohydrate': 6.32,
#   'sugars': 0.0},
#  'Fish, raw, florida, pompano': {'calories': 164,
#   'total_fat': 9.5,
#   'protein': 18.48,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  'Potato salad, home-prepared': {'calories': 143,
#   'total_fat': 8.2,
#   'protein': 2.68,
#   'carbohydrate': 11.17,
#   'sugars': 0.0},
#  'GIRL SCOUTS, Chalet Cookies': {'calories': 478,
#   'total_fat': 19.0,
#   'protein': 4.2,
#   'carbohydrate': 72.3,
#   'sugars': 35.4},
#  'GIRL SCOUTS, Samoas Cookies': {'calories': 489,
#   'total_fat': 26.0,
#   'protein': 3.5,
#   'carbohydrate': 64.1,
#   'sugars': 35.8},
#  'Cheese, semisoft type, goat': {'calories': 364,
#   'total_fat': 30.0,
#   'protein': 21.58,
#   'carbohydrate': 0.12,
#   'sugars': 0.12},
#  'Game meat, raw, ground, elk': {'calories': 172,
#   'total_fat': 8.8,
#   'protein': 21.76,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  'Candies, unsweetened, carob': {'calories': 540,
#   'total_fat': 31.0,
#   'protein': 8.15,
#   'carbohydrate': 56.29,
#   'sugars': 34.11},
#  'Babyfood, toddler, potatoes': {'calories': 52,
#   'total_fat': 0.1,
#   'protein': 1.0,
#   'carbohydrate': 11.73,
#   'sugars': 0.91},
#  'Veal, cooked, seam fat only': {'calories': 505,
#   'total_fat': 50.0,
#   'protein': 11.16,
#   'carbohydrate': 2.11,
#   'sugars': 0.0},
#  'Sauce, ready-to-serve, duck': {'calories': 245,
#   'total_fat': 0.1,
#   'protein': 0.36,
#   'carbohydrate': 60.61,
#   'sugars': 30.54},
#  'Corn dogs, prepared, frozen': {'calories': 250,
#   'total_fat': 12.0,
#   'protein': 8.57,
#   'carbohydrate': 26.96,
#   'sugars': 7.54},
#  'Seeds, paste, sesame butter': {'calories': 586,
#   'total_fat': 51.0,
#   'protein': 18.08,
#   'carbohydrate': 24.05,
#   'sugars': 0.0},
#  'Noodles, enriched, dry, egg': {'calories': 384,
#   'total_fat': 4.4,
#   'protein': 14.16,
#   'carbohydrate': 71.27,
#   'sugars': 1.88},
#  'Persimmons, dried, japanese': {'calories': 274,
#   'total_fat': 0.6,
#   'protein': 1.38,
#   'carbohydrate': 73.43,
#   'sugars': 0.0},
#  'Carrots, unprepared, frozen': {'calories': 36,
#   'total_fat': 0.5,
#   'protein': 0.78,
#   'carbohydrate': 7.9,
#   'sugars': 4.76},
#  'Carambola, raw, (starfruit)': {'calories': 31,
#   'total_fat': 0.3,
#   'protein': 1.04,
#   'carbohydrate': 6.73,
#   'sugars': 3.98},
#  'Fast foods, chicken tenders': {'calories': 271,
#   'total_fat': 14.0,
#   'protein': 19.22,
#   'carbohydrate': 17.25,
#   'sugars': 0.4},
#  'Beans, home prepared, baked': {'calories': 155,
#   'total_fat': 5.2,
#   'protein': 5.54,
#   'carbohydrate': 21.63,
#   'sugars': 0.0},
#  'Cream, half and half, fluid': {'calories': 123,
#   'total_fat': 10.0,
#   'protein': 3.13,
#   'carbohydrate': 4.73,
#   'sugars': 4.13},
#  'SILK Light Vanilla, soymilk': {'calories': 33,
#   'total_fat': 0.8,
#   'protein': 2.47,
#   'carbohydrate': 4.12,
#   'sugars': 2.88},
#  'Turnips, unprepared, frozen': {'calories': 16,
#   'total_fat': 0.2,
#   'protein': 1.04,
#   'carbohydrate': 2.94,
#   'sugars': 0.0},
#  'PACE, Cilantro Chunky Salsa': {'calories': 25,
#   'total_fat': 0.0,
#   'protein': 0.0,
#   'carbohydrate': 6.25,
#   'sugars': 6.25},
#  'PACE, Chipotle Chunky Salsa': {'calories': 25,
#   'total_fat': 0.0,
#   'protein': 0.0,
#   'carbohydrate': 6.25,
#   'sugars': 6.25},
#  'Jams and preserves, apricot': {'calories': 242,
#   'total_fat': 0.2,
#   'protein': 0.7,
#   'carbohydrate': 64.4,
#   'sugars': 43.4},
#  'Butter, with salt, whipped': {'calories': 718,
#   'total_fat': 78.0,
#   'protein': 0.49,
#   'carbohydrate': 2.87,
#   'sugars': 0.06},
#  'Ham, cooked, smoked, honey': {'calories': 122,
#   'total_fat': 2.4,
#   'protein': 17.93,
#   'carbohydrate': 7.27,
#   'sugars': 0.0},
#  'Spaghetti, cooked, spinach': {'calories': 130,
#   'total_fat': 0.6,
#   'protein': 4.58,
#   'carbohydrate': 26.15,
#   'sugars': 0.0},
#  'Bockwurst, raw, veal, pork': {'calories': 301,
#   'total_fat': 26.0,
#   'protein': 14.03,
#   'carbohydrate': 2.95,
#   'sugars': 1.33},
#  'Guinea hen, raw, meat only': {'calories': 110,
#   'total_fat': 2.5,
#   'protein': 20.64,
#   'carbohydrate': 0.0,
#   'sugars': 0.0},
#  'Cookies, soft-type, raisin': {'calories': 401,
#   'total_fat': 14.0,
#   'protein': 4.1,
#   'carbohydrate': 68.0,
#   'sugars': 47.56},
#  'Squash, raw, acorn, winter': {'calories': 40,
#   'total_fat': 0.1,
#   'protein': 0.8,
#   'carbohydrate': 10.42,
#   'sugars': 0.0},
#  ...}

# %%
nutrition_dict['Croissants, cheese']['calories']
# Out:
# 414

# %%
# Start coding here!
# Use as many cells as you need.

food_dict = {
             "Croissants, cheese": 150, 
             "Orange juice, raw": 250
            }

def nutritional_summary(food_dict: dict):

    nutritions_keys = ["calories", "total_fat", "protein", "carbohydrate", "sugars"]
    summary = dict.fromkeys(nutritions_keys, 0)

    for food, grams in food_dict.items():

        if not isinstance(grams, (int, float)) or grams <= 0:
            raise ValueError(f"Invalid weight for '{food}': must be a positive number.")

        if food not in nutrition_dict:
            return food

        for key in nutritions_keys:
            summary[key] += (grams * nutrition_dict[food][key]) / 100
    return summary


nutritional_summary(food_dict)
# Out:
# {'calories': 733.5,
#  'total_fat': 32.0,
#  'protein': 15.55,
#  'carbohydrate': 96.5,
#  'sugars': 38.025}

# %%
nutritional_summary({"Croissant": 150, "Orange juice": 250})
# Out:
# 'Croissant'

# %% [markdown]
# # Solution

# %%
import json  # Import the json module to work with JSON files

# Open the nutrition.json file in read mode and load its content into a dictionary
with open('nutrition.json', 'r') as json_file:
    nutrition_dict = json.load(json_file)  # Load the JSON content into a dictionary
    
# Display the first 3 items of the nutrition dictionary
list(nutrition_dict.items())[:3]

# Define a function to calculate the nutritional summary given a dictionary of foods and their weights
def nutritional_summary(foods):
    # Initialize result dictionary to store total nutritional values
    result_dict = {"calories": 0, "total_fat": 0, "protein": 0, "carbohydrate": 0, "sugars": 0} 
    
    # Process each food item
    for name, grams in foods.items():
        if name in nutrition_dict:
            # Get the nutritional information for the food item
            nutrition = nutrition_dict[name]
            # Calculate and add the nutritional values based on the given weight (grams)
            result_dict["calories"] += grams * nutrition["calories"] / 100
            result_dict["total_fat"] += grams * nutrition["total_fat"] / 100
            result_dict["protein"] += grams * nutrition["protein"] / 100
            result_dict["carbohydrate"] += grams * nutrition["carbohydrate"] / 100
            result_dict["sugars"] += grams * nutrition["sugars"] / 100
        else:
            # Return the name of the first food item not found in the nutrition_dict
            return name
    # Return the total nutritional values
    return result_dict

# Calling the function and checking the output
print(nutritional_summary({"Croissants, cheese": 150, "Orange juice, raw": 250}))
print(nutritional_summary({"Croissant": 150, "Orange juice": 250}))
# Out:
# {'calories': 733.5, 'total_fat': 32.0, 'protein': 15.55, 'carbohydrate': 96.5, 'sugars': 38.025}
# Croissant
