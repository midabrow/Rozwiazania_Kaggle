# %% [markdown]
# <a id="intro"></a>
# # <a id='toc2_'></a>[<p style="background-color:#1E3A8A; font-family:calibri; font-size:130%; color:white; text-align:center; border-radius:0px 0px; padding:10px">Step 1 | Introduction 👋</p>](#toc0_)
#
# ⬆️ [Tabel of Contents](#contents_tabel)

# %% [markdown]
# <a id="problem"></a>
# # <a id='toc3_'></a>[<b><span style='color:darkorange'>🤔 Dataset Problem</span></b>](#toc0_)

# %% [markdown]
# <style>
#     .underline-yellow {
#         background-color: #FFAA33;
#         color: black;
#         font-weight: bold;
#         padding: 2px 4px;
#     }
#     .explain-box {
#         background-color:;
#         border-left: 6px solid #FFAA33;
#         padding: 16px;
#         font-family: Arial, sans-serif;
#         font-size: 15px;
#         line-height: 1.6;
#         margin-top: 12px;
#     }
# </style>
#
# <div class="explain-box"> The <b>Car Price Prediction</b> dataset contains information about used cars (e.g., model, brand, year, fuel type, transmission, mileage, etc.) along with the target variable – their <span class="underline-yellow">market price</span>. <br><br> The goal is to build a machine learning model that can accurately predict the <span class="underline-yellow">price of a car based on its characteristics</span>. <br><br> This is a typical example of a <span class="underline-yellow">supervised regression problem</span>, where the model learns the mapping from input features (like year, mileage, engine size) to a continuous output (price). <br><br> The dataset includes a mix of <b>numerical</b> and <b>categorical</b> features, making it a great case study for <i>feature engineering</i>, <i>encoding strategies</i>, and <i>MLP modeling in PyTorch</i>. </div>

# %% [markdown]
# <a id="objectives"></a>
# # <a id='toc4_'></a>[<b><span style='color:darkorange'>📌 Notebook Objectives</span></b>](#toc0_)

# %% [markdown]
# ### **_Project Goal:_**
#
# Build and train a PyTorch-based MLP regression model that can predict the **market price of used cars** from a set of features such as brand, year, transmission, mileage, and fuel type.
#
# This is a regression task involving structured tabular data, making it an ideal challenge to practice **feature preprocessing**, **deep learning with non-image data**, and **evaluation of regression performance**.
#
# * * *
#
# ### **_Key Steps:_**
#
# #### 1\. **Understand the problem**
#
# -   Predict car prices based on available structured features.
#
# -   The target is a **continuous variable** (regression).
#
# -   The dataset contains **categorical** and **numerical** features.
#
#
# #### 2\. **Data exploration (EDA)**
#
# -   Analyze the distribution of the target variable (price).
#
# -   Understand the value ranges and cardinality of each feature.
#
# -   Identify potential outliers, missing values, skewness.
#
#
# #### 3\. **Data preprocessing**
#
# -   Fill or remove missing values.
#
# -   Encode categorical features (e.g., Label Encoding or One-Hot).
#
# -   Normalize numerical columns (e.g., mileage, engine size).
#
# -   Prepare `X` and `y` for PyTorch model (train/test split, tensors).
#
#
# #### 4\. **Build MLP model**
#
# -   Define a **regression MLP** using PyTorch (`nn.Module`).
#
#     -   Input layer: feature size
#
#     -   Hidden layers: Linear + ReLU
#
#     -   Output layer: 1 neuron (for continuous price)
#
# -   Use `MSELoss` and `Adam` optimizer.
#
#
# #### 5\. **Train and evaluate**
#
# -   Train over several epochs and track loss.
#
# -   Evaluate performance using:
#
#     -   RMSE
#
#     -   MAE
#
#     -   R² Score
#
# -   Visualize predictions vs true prices.
#
#
# #### 6\. **Summary and improvements**
#
# -   Analyze which features influence the model most.
#
# -   Identify under/over-fitting.
#
# -   Consider future steps:
#
#     -   Hyperparameter tuning
#
#     -   Model ensembles
#
#     -   Other regression architectures

# %% [markdown]
# <a id="description"></a>
# # <a id='toc6_'></a>[<b><span style='color:darkorange'>🧾 Dataset Description</span></b>](#toc0_)

# %% [markdown]
# <style>
#     table {
#         width: 100%;
#         border-collapse: collapse;
#         font-family: Arial, sans-serif;
#     }
#     th, td {
#         border: 1px solid #ddd;
#         padding: 8px;
#         text-align: left;
#     }
#     th {
#         background-color: #FFAA33;
#         color: black;
#         font-weight: bold;
#     }
#     tr:nth-child(even) {
#         background-color: ;
#     }
# </style>
#
# <table> <tr> <th>Feature</th> <th>Description</th> <th>Type</th> <th>Example</th> </tr> <tr> <td><b>Car_Name</b></td> <td>Name_model of the car</td> <td>String (categorical)</td> <td>"Maruti Swift Dzire"</td> </tr> <tr> <td><b>Year</b></td> <td>Year of purchase</td> <td>Integer</td> <td>2015</td> </tr> <tr> <td><b>Selling_Price</b></td> <td>Target variable – price in lakhs</td> <td>Float</td> <td>3.35</td> </tr> <tr> <td><b>Present_Price</b></td> <td>Price of the car when bought new</td> <td>Float</td> <td>5.59</td> </tr> <tr> <td><b>Kms_Driven</b></td> <td>Total kilometers driven</td> <td>Integer</td> <td>27000</td> </tr> <tr> <td><b>Fuel_Type</b></td> <td>Type of fuel used</td> <td>String (categorical)</td> <td>"Petrol", "Diesel", "CNG"</td> </tr> <tr> <td><b>Seller_Type</b></td> <td>Individual or Dealer</td> <td>String (categorical)</td> <td>"Individual"</td> </tr> <tr> <td><b>Transmission</b></td> <td>Manual or Automatic</td> <td>String (categorical)</td> <td>"Manual"</td> </tr> <tr> <td><b>Owner</b></td> <td>Number of previous owners</td> <td>Integer</td> <td>0, 1, 2</td> </tr> </table>

# %% [markdown]
# <a id="import_install"></a>
# # <a id='toc7_'></a>[<p style="background-color:#1E3A8A; font-family:calibri; font-size:130%; color:white; text-align:center; border-radius:0px 0px; padding:10px">Step 2 | Installing and importing Libraries 📚</p>](#toc0_)
#
#
# ⬆️ [Tabel of Contents](#contents_tabel)

# %% [markdown]
# <a id="install"></a>
# # <a id='toc8_'></a>[<b><span style='color:darkorange'>Step 2.1 |</span><span style='color:#1E3A8A'> Installing Libraries</span></b>](#toc0_)

# %%
# ⚙️ Installing required libraries (if running locally, uncomment and run this cell)
# !pip install torch torchvision
# !pip install numpy pandas
# !pip install matplotlib seaborn plotly ydata_profiling
# !pip install termcolor

# %% [markdown]
# <a id="import"></a>
# # <a id='toc9_'></a>[<b><span style='color:darkorange'>Step 2.2 |</span><span style='color:#1E3A8A'> Importing Libraries</span></b>](#toc0_)

# %%
# %load_ext autoreload
# %autoreload 2
# ============================
# 🧠 PyTorch – Model, Datasets, Transformacje
# ============================
import torch
from torch import nn
from torchvision import datasets
from torchvision.transforms import ToTensor
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset, random_split

# ============================
# 📊 Data analysis and processing
# ============================
import pandas as pd
import numpy as np
from ydata_profiling import ProfileReport
import missingno as msno

# ============================
# 📈 Visualization – Matplotlib, Seaborn, Plotly
# ============================
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import colors

import plotly.graph_objs as go
from plotly.subplots import make_subplots

# Dla Jupyter Notebooka – wyświetlanie wykresów
import plotly.io as pio
pio.renderers.default = 'notebook'
# pio.renderers.default = 'browser' 

# %matplotlib inline

# ============================
# ⚙️ Tools and Warnings
# ============================
import warnings
from termcolor import colored

# ============================
# 💉 Helpers
# ============================
import helpers as hp

# ============================
# ✅ Import confirmation
# ============================
print(colored('\n✅ All libraries imported successfully.', 'green'))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#
# ✅ All libraries imported successfully.

# %% [markdown]
# <a id="lib_config"></a>
# # <a id='toc10_'></a>[<b><span style='color:darkorange'>Step 2.3 |</span><span style='color:#1E3A8A'> Library configuration</span></b>](#toc0_)

# %%
pd.options.mode.copy_on_write = True # Allow re-write on variable
sns.set_style('darkgrid') # Seaborn style
warnings.filterwarnings('ignore') # Ignore warnings
pd.set_option('display.max_columns', None) # Setting this option will print all collumns of a dataframe
pd.set_option('display.max_colwidth', None) # Setting this option will print all of the data in a feature

sns.color_palette("cool_r", n_colors=1)
sns.set_palette("cool_r")

print(colored('\nAll libraries configured succesfully.', 'green'))
# Out:
# All libraries configured succesfully.

# %% [markdown]
# <a id="coloring"></a>
# # <a id='toc10_'></a>[<b><span style='color:darkorange'>Step 2.4 |</span><span style='color:#1E3A8A'> Coloring console output</span></b>](#toc0_)

# %%
class clr:
    bold = '\033[1m'             
    orange = '\033[38;5;208m'  
    blue = '\033[38;5;75m'    
    reset = '\033[0m' 

    @staticmethod
    def print_colored_text():
        print(clr.orange + "This is dark orange text!" + clr.reset)
        print(clr.blue + "This is light blue text!" + clr.reset)
        print(clr.bold + "This is bold text!" + clr.reset)
        print(clr.bold + clr.orange + "This is bold dark orange text!" + clr.reset)

# Testowanie
clr.print_colored_text()
# Out:
# This is dark orange text!
# This is light blue text!
# This is bold text!
# This is bold dark orange text!

# %% [markdown]
# <a id="overview"></a>
# # <a id='toc11_'></a>[<p style="background-color:#1E3A8A; font-family:calibri; font-size:130%; color:white; text-align:center; border-radius:0px 0px; padding:10px">Step 3 | Reading Dataset 👓</p>](#toc0_)
#
#
# ⬆️ [Tabel of Contents](#contents_tabel)

# %%
data = pd.read_csv('./data/car_data.csv')
df = data.copy(deep=True)

df.head().style.background_gradient(cmap='PuBu')
# Out:
# <style type="text/css">
# #T_b7062_row0_col1, #T_b7062_row4_col1 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_b7062_row0_col2 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_b7062_row0_col3 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_b7062_row0_col4 {
#   background-color: #4e9ac6;
#   color: #f1f1f1;
# }
# #T_b7062_row0_col8, #T_b7062_row1_col8, #T_b7062_row2_col8, #T_b7062_row3_col1, #T_b7062_row3_col2, #T_b7062_row3_col3, #T_b7062_row3_col4, #T_b7062_row3_col8, #T_b7062_row4_col8 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_b7062_row1_col1 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_b7062_row1_col2 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_b7062_row1_col3 {
#   background-color: #03466e;
#   color: #f1f1f1;
# }
# #T_b7062_row1_col4, #T_b7062_row2_col1, #T_b7062_row2_col2, #T_b7062_row2_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_b7062_row2_col4 {
# ...

# %% [markdown]
# <a id="profiling"></a>
# # <a id='toc12_'></a>[<p style="background-color:#1E3A8A; font-family:calibri; font-size:130%; color:white; text-align:center; border-radius:0px 0px; padding:10px">Step 4 | Data Profiling 🔍</p>](#toc0_)
#
#
# ⬆️ [Tabel of Contents](#contents_tabel)

# %% [markdown]
# <a id="df_train_profile"></a>
# # <a id='toc13_'></a>[<b><span style='color:darkorange'>Step 4.1 |</span><span style='color:#1E3A8A'> Dataset Report</span></b>](#toc0_)

# %%
profile = ProfileReport(df, title='Dataset Profile')

profile.to_notebook_iframe()
# Out:
# ...
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  1.37it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;YData Profiling vv4.16.1&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2025-04-18 09:41:23.331494&quot;&gt;&lt;title&gt;Dataset Profile&lt;/title&gt;&lt;style&gt;
# @charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...

# %% [markdown]
# <a id="data_wrangling"></a>
# # <a id='toc15_'></a>[<p style="background-color:#1E3A8A; font-family:calibri; font-size:130%; color:white; text-align:center; border-radius:0px 0px; padding:10px">Step 5 | Data Wrangling 📈</p>](#toc0_)
#
#
# ⬆️ [Tabel of Contents](#contents_tabel)

# %% [markdown]
# <a id="wrangling_overview"></a>
# # <a id='toc16_'></a>[<b><span style='color:darkorange'>Step 5.1 |</span><span style='color:#1E3A8A'> Dataset overview</span></b>](#toc0_)

# %%
df.head(n=10)
# Out:
#         Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0           ritz  2014           3.35           5.59       27000    Petrol
# 1            sx4  2013           4.75           9.54       43000    Diesel
# 2           ciaz  2017           7.25           9.85        6900    Petrol
# 3        wagon r  2011           2.85           4.15        5200    Petrol
# 4          swift  2014           4.60           6.87       42450    Diesel
# 5  vitara brezza  2018           9.25           9.83        2071    Diesel
# 6           ciaz  2015           6.75           8.12       18796    Petrol
# 7        s cross  2015           6.50           8.61       33429    Diesel
# 8           ciaz  2016           8.75           8.89       20273    Diesel
# 9           ciaz  2015           7.45           8.92       42367    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# ...

# %% [markdown]
# <a id="wrangling_num_of_records"></a>
# # <a id='toc17_'></a>[<b><span style='color:darkorange'>Step 5.2 |</span><span style='color:#1E3A8A'> Number of records and columns</span></b>](#toc0_)

# %%
dataset_name = 'Car Prices'
print(clr.orange + f'🍷 {dataset_name} Dataset has {df.shape[0]} rows and {df.shape[1]} columns' + clr.reset)
# Out:
# 🍷 Car Prices Dataset has 301 rows and 9 columns

# %% [markdown]
# <a id="wrangling_basic_info"></a>
# # <a id='toc18_'></a>[<b><span style='color:darkorange'>Step 5.3 |</span><span style='color:#1E3A8A'> Basic Info</span></b>](#toc0_)

# %%
print(clr.orange + f"\n{'='*50}")
print(f'🔍 Basic Info - {dataset_name} Dataset')
print(f"{'='*50}" + clr.reset)
df.info()
# Out:
# ...
# 🔍 Basic Info - Car Prices Dataset
# ...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %% [markdown]
# <a id="wrangling_unique_vals"></a>
# # <a id='toc19_'></a>[<b><span style='color:darkorange'>Step 5.4 |</span><span style='color:#1E3A8A'> Unique Values</span></b>](#toc0_)

# %%
hp.check_unique_values(df, dataset_name)
# Out:
# ...
# 🔍 Unique Values Report for: Car Prices
# ...
#
# Number of unique values per column:
# Car_Name          98
# Year              16
# Selling_Price    156
# Present_Price    147
# Kms_Driven       206
# Fuel_Type          3
# Seller_Type        2
# Transmission       2
# Owner              3
# dtype: int64
#
# Unique values in column 'Car_Name':
# ['ritz' 'sx4' 'ciaz' 'wagon r' 'swift' 'vitara brezza' 's cross'
#  'alto 800' 'ertiga' 'dzire' 'alto k10' 'ignis' '800' 'baleno' 'omni'
#  'fortuner' 'innova' 'corolla altis' 'etios cross' 'etios g' 'etios liva'
#  'corolla' 'etios gd' 'camry' 'land cruiser' 'Royal Enfield Thunder 500'
#  'UM Renegade Mojave' 'KTM RC200' 'Bajaj Dominar 400'
#  'Royal Enfield Classic 350' 'KTM RC390' 'Hyosung GT250R'
#  'Royal Enfield Thunder 350' 'KTM 390 Duke ' 'Mahindra Mojo XT300'
#  'Bajaj Pulsar RS200' 'Royal Enfield Bullet 350'
#  'Royal Enfield Classic 500' 'Bajaj Avenger 220' 'Bajaj Avenger 150'
# ...

# %% [markdown]
# <a id="wrangling_missing_vals"></a>
# # <a id='toc20_'></a>[<b><span style='color:darkorange'>Step 5.5 |</span><span style='color:#1E3A8A'> Missing Values</span></b>](#toc0_)

# %%
hp.report_missing_data(df, dataset_name)
# Out:
# 🔴 Missing Data Report for: Car Prices
# --------------------------------------------------
# Empty DataFrame
# Columns: [Total, Percent]
# Index: []

# %% [markdown]
# <style>
#     .underline-red {
#         background-color: #1E3A8A;
#         color: white;
#         font-size: 14px;
#         font-family: Arial, sans-serif;
#         font-weight: bold;
#         padding: 2px 5px;
#         border-radius: 4px;
#     }
#
#     .container {
#         border-radius: 10px;
#         border: 2px solid maroon;
#         padding: 15px;
#         background-color: #a3adc7; /* bardziej przejrzyste */
#         color: #ffffff;
#         font-size: 110%;
#         text-align: left;
#     }
#
#     h3 {
#         color: #1E3A8A;
#         font-weight: bold;
#     }
#
#     ul {
#         color: black;
#         padding-left: 20px;
#     }
# </style>
#
# <div class="container">
#
#   <h3 align="left">Key Observations:</h3>
#
#   <ul>
#     <li><span class="underline-red">Missing values</span>
#       <div>- There are no missing values ​​in the set. No action required.</div>
#     </li>
#   </ul>
#
# </div>

# %% [markdown]
# <a id="wrangling_nums_cols"></a>
# # <a id='toc21_'></a>[<b><span style='color:darkorange'>Step 5.6 |</span><span style='color:#1E3A8A'> More info about numerical types</span></b>](#toc0_)

# %%
df.describe().T.style.background_gradient(axis=0)
# Out:
# <style type="text/css">
# #T_b7190_row0_col0, #T_b7190_row0_col2, #T_b7190_row1_col0, #T_b7190_row1_col1, #T_b7190_row1_col2, #T_b7190_row1_col3, #T_b7190_row1_col4, #T_b7190_row1_col5, #T_b7190_row1_col6, #T_b7190_row1_col7, #T_b7190_row2_col0, #T_b7190_row2_col1, #T_b7190_row2_col2, #T_b7190_row2_col3, #T_b7190_row2_col4, #T_b7190_row2_col5, #T_b7190_row2_col6, #T_b7190_row2_col7, #T_b7190_row3_col0, #T_b7190_row4_col0, #T_b7190_row4_col1, #T_b7190_row4_col2, #T_b7190_row4_col3, #T_b7190_row4_col4, #T_b7190_row4_col5, #T_b7190_row4_col6, #T_b7190_row4_col7 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_b7190_row0_col1 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_b7190_row0_col3, #T_b7190_row3_col1, #T_b7190_row3_col2, #T_b7190_row3_col4, #T_b7190_row3_col5, #T_b7190_row3_col6, #T_b7190_row3_col7 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_b7190_row0_col4 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# ...

# %%
numerical_cols = df.select_dtypes(include='number').columns.to_list()
numerical_cols
# Out:
# ['Year', 'Selling_Price', 'Present_Price', 'Kms_Driven', 'Owner']

# %%
hp.plot_numerical_distributions(df, numerical_cols)

# %% [markdown]
# <a id="wrangling_duplicates"></a>
# # <a id='toc23_'></a>[<b><span style='color:darkorange'>Step 5.7 |</span><span style='color:#1E3A8A'> Duplicates</span></b>](#toc0_)

# %%
hp.check_duplicates(df, dataset_name)
# Out:
# ...
# 🔍 Report for: Car Prices
# ...
#
# Total number of duplicate rows: 2
#
# Duplicate rows in the dataset:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 17    ertiga  2016           7.75          10.79       43000    Diesel
# 93  fortuner  2015          23.00          30.61       40000    Diesel
#
#    Seller_Type Transmission  Owner
# 17      Dealer       Manual      0
# 93      Dealer    Automatic      0
#
# Checking duplicates in each column:
# Column 'Car_Name' has 203 duplicate values
# Column 'Year' has 285 duplicate values
# Column 'Selling_Price' has 145 duplicate values
# Column 'Present_Price' has 154 duplicate values
# Column 'Kms_Driven' has 95 duplicate values
# Column 'Fuel_Type' has 298 duplicate values
# Column 'Seller_Type' has 299 duplicate values
# Column 'Transmission' has 299 duplicate values
# Column 'Owner' has 298 duplicate values
# ...

# %% [markdown]
# <a id="wrangling_outliers"></a>
# # <a id='toc24_'></a>[<b><span style='color:darkorange'>Step 5.9 |</span><span style='color:#1E3A8A'> Outliers</span></b>](#toc0_)

# %% [markdown]
# <style>
#     .underline-red {
#         background-color: #FFAA33;;
#         color: black;
#         font-size: 14px;
#         font-family: Arial, sans-serif;
#         font-weight: bold;
#         padding: 2px 5px;
#         border-radius: 4px;
#     }
# </style>
#
# <div class="explain-box">
# Results are provided for two methods:
#
# 1. <span class="underline-red"><b>IQR (Interquartile Range)</b></span>
#
# - Values considered outliers are <b>below</b> the first quartile (<span class="underline-red">Q1 - 1.5 × IQR</span>) or <b>above</b> the third quartile (<span class="underline-red">Q3 + 1.5 × IQR</span>).
#
# - This is a more classical method, less sensitive to extreme values.
#
# 2. <span class="underline-red"><b>Z-score (standardized Z-value)</b></span>
#
# - Values for which <b>Z-score modulus > 3</b> are considered outliers.
#
# - This method is more sensitive to the distribution of the data – if the data is not normally distributed, it may produce misleading results.
# </div>

# %%
columns = list(df.select_dtypes(include='number').columns)
columns
# Out:
# ['Year', 'Selling_Price', 'Present_Price', 'Kms_Driven', 'Owner']

# %%
cols_without_target = [col for col in columns if col != 'Selling_Price']
cols_without_target
# Out:
# ['Year', 'Present_Price', 'Kms_Driven', 'Owner']

# %%
hp.check_outliers(df, dataset_name, numerical_cols=cols_without_target, target_col='Selling_Price')
# Out:
# ...
# 🔍 Outliers Report for: Car Prices
# ...
#
# 📊 Checking outliers in column:Year
# 📌 Outliers based on IQR (<= 2006.00 or >= 2022.00):7 values
#     Year
# 37  2003
# 39  2003
# 54  2005
# 77  2004
# 84  2005
# 📌 Outliers based on Z-score (>|3|):3 values
#     Year
# 37  2003
# 39  2003
# 77  2004
#
# 📊 Checking outliers in column:Present_Price
# 📌 Outliers based on IQR (<= -11.85 or >= 22.95):14 values
#     Present_Price
# 50          30.61
# 51          30.61
# 53          30.61
# 59          35.96
# 62          35.96
# 📌 Outliers based on Z-score (>|3|):5 values
#     Present_Price
# 59          35.96
# 62          35.96
# 63          35.96
# 64          36.23
# 86          92.60
#
# 📊 Checking outliers in column:Kms_Driven
# 📌 Outliers based on IQR (<= -35650.50 or >= 99417.50):8 values
#     Kms_Driven
# 37      127000
# 50      104707
# 53      135000
# 77      135154
# 84      197176
# 📌 Outliers based on Z-score (>|3|):3 values
#      Kms_Driven
# 84       197176
# 179      213000
# ...

# %% [markdown]
# <a id="cleaning"></a>
# # <a id='toc25_'></a>[<p style="background-color:#1E3A8A; font-family:calibri; font-size:130%; color:white; text-align:center; border-radius:0px 0px; padding:10px">Step 6 | Cleaning data 📈</p>](#toc0_)
#
#
# ⬆️ [Tabel of Contents](#contents_tabel)

# %% [markdown]
# <a id="cleaning_missing_vals"></a>
# # <a id='toc26_'></a>[<b><span style='color:darkorange'>Step 6.1 |</span><span style='color:#1E3A8A'> Handling missing values (imputation or removal)  </span></b>](#toc0_)

# %% [markdown]
# There is no missing data

# %% [markdown]
# <a id="cleaning_columns_names"></a>
# # <a id='toc27_'></a>[<b><span style='color:darkorange'>Step 6.2 |</span><span style='color:#1E3A8A'> Standardizing column names and values</span></b>](#toc0_)

# %%
hp.clean_column_names(df, dataset_name, to_lower=True)
# Out:
# ...
# 🔍 Checking and cleaning column names for: Car Prices
# ...
#
# Original column names: ['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven', 'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner']
#
# Cleaned column names: ['car_name', 'year', 'selling_price', 'present_price', 'kms_driven', 'fuel_type', 'seller_type', 'transmission', 'owner']
#
# ✅ No duplicate columns found.

# %% [markdown]
# <a id="cleaning_standarization"></a>
# # <a id='toc28_'></a>[<b><span style='color:darkorange'>Step 6.3 |</span><span style='color:#1E3A8A'> Standardization of data types  </span></b>](#toc0_)

# %%
df.dtypes
# Out:
# car_name          object
# year               int64
# selling_price    float64
# present_price    float64
# kms_driven         int64
# fuel_type         object
# seller_type       object
# transmission      object
# owner              int64
# dtype: object

# %% [markdown]
# <style>
#     .underline-blue {
#         background-color: #1E3A8A;
#         color: white;
#         font-size: 14px;
#         font-family: Arial, sans-serif;
#         font-weight: bold;
#         padding: 2px 5px;
#         border-radius: 4px;
#     }
#     .underline-orange {
#         background-color: #FFAA33;
#         color: black;
#         font-size: 14px;
#         font-family: Arial, sans-serif;
#         font-weight: bold;
#         padding: 2px 5px;
#         border-radius: 4px;
#     }
#
#     .container {
#         border-radius: 10px;
#         border: 2px solid maroon;
#         padding: 15px;
#         background-color: #a3adc7;
#         color: #ffffff;
#         font-size: 110%;
#         text-align: left;
#     }
#
#     h3 {
#         color: #1E3A8A;
#         font-weight: bold;
#     }
#
#     ul {
#         color: black;
#         padding-left: 20px;
#     }
# </style>
#
# <div class="container">
#   <h3 align="left">Key Observations:</h3>
#   ✅ <b>Conclusion</b>: There is no need for standardization of data types. Everything is in the right formats.
# </div>

# %% [markdown]
# <a id="model-building"></a>
# # <a id='toc11_'></a>[<p style="background-color:#1E3A8A; font-family:calibri; font-size:130%; color:white; text-align:center; border-radius:0px 0px; padding:10px">Step 7 | Model Building 🤖</p>](#toc0_)
#
#
# ⬆️ [Tabel of Contents](#contents_tabel)

# %% [markdown]
# <a id="data-prep"></a>
# # <a id='toc10_'></a>[<b><span style='color:darkorange'>Step 7.1 |</span><span style='color:#1E3A8A'> Data Preparation</span></b>](#toc0_)

# %%
input_cols = [col for col in df.select_dtypes(include='number').columns if col != 'selling_price']
categorical_cols = df.select_dtypes(include='object').columns
output_cols = ['selling_price']

# %%
def dataframe_to_arrays(dataframe):
    dataframe_copy = df.copy(deep=True)
    
    for col in categorical_cols:
        dataframe_copy[col] = dataframe_copy[col].astype('category').cat.codes

    input_array = dataframe_copy[input_cols].to_numpy()
    target_array = dataframe_copy[output_cols].to_numpy()

    return input_array, target_array

input_array, target_array = dataframe_to_arrays(df)
input_array
# Out:
# (array([[2.0140e+03, 5.5900e+00, 2.7000e+04, 0.0000e+00],
#         [2.0130e+03, 9.5400e+00, 4.3000e+04, 0.0000e+00],
#         [2.0170e+03, 9.8500e+00, 6.9000e+03, 0.0000e+00],
#         ...,
#         [2.0090e+03, 1.1000e+01, 8.7934e+04, 0.0000e+00],
#         [2.0170e+03, 1.2500e+01, 9.0000e+03, 0.0000e+00],
#         [2.0160e+03, 5.9000e+00, 5.4640e+03, 0.0000e+00]]),)

# %%
target_array
# Out:
# array([[ 3.35],
#        [ 4.75],
#        [ 7.25],
#        [ 2.85],
#        [ 4.6 ],
#        [ 9.25],
#        [ 6.75],
#        [ 6.5 ],
#        [ 8.75],
#        [ 7.45],
#        [ 2.85],
#        [ 6.85],
#        [ 7.5 ],
#        [ 6.1 ],
#        [ 2.25],
#        [ 7.75],
#        [ 7.25],
#        [ 7.75],
#        [ 3.25],
#        [ 2.65],
#        [ 2.85],
#        [ 4.9 ],
#        [ 4.4 ],
#        [ 2.5 ],
#        [ 2.9 ],
#        [ 3.  ],
#        [ 4.15],
#        [ 6.  ],
#        [ 1.95],
#        [ 7.45],
#        [ 3.1 ],
#        [ 2.35],
#        [ 4.95],
#        [ 6.  ],
#        [ 5.5 ],
#        [ 2.95],
#        [ 4.65],
#        [ 0.35],
#        [ 3.  ],
#        [ 2.25],
#        [ 5.85],
#        [ 2.55],
#        [ 1.95],
#        [ 5.5 ],
#        [ 1.25],
#        [ 7.5 ],
#        [ 2.65],
#        [ 1.05],
#        [ 5.8 ],
#        [ 7.75],
#        [14.9 ],
#        [23.  ],
#        [18.  ],
#        [16.  ],
#        [ 2.75],
# ...

# %%
input = torch.Tensor(input_array)
target = torch.Tensor(target_array)

dataset = TensorDataset(input, target)

# 80% and 20%
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size

train_ds, val_ds = random_split(dataset, [train_size, val_size])

batch_size = 128

train_loader = DataLoader(dataset, batch_size, shuffle=True)
val_loader = DataLoader(val_ds, batch_size)

# %% [markdown]
# <a id="creating-model"></a>
# # <a id='toc10_'></a>[<b><span style='color:darkorange'>Step 7.2 |</span><span style='color:#1E3A8A'> Creating model</span></b>](#toc0_)

# %%
input_size = len(input_cols)
output_size = len(output_cols)



class CarsModel(nn.Module):
    def __init__(self):
        super().__init__()
        # to `nn.Linear(6, 1)` = jedna warstwa, która uczy się mapować cechy → cena.
        self.linear = nn.Linear(input_size, output_size)

    # mówi: „jak dane przechodzą przez model”
    def forward(self, xb):
        out = self.linear(xb)
        return out
    
    # „co się dzieje podczas 1 kroku treningowego”.
    def training_step(self, batch):
        inputs, targets = batch
        # Robi predykcję out = self(inputs)
        out = self(inputs)
        # Oblicza błąd (L1 = MAE – Mean Absolute Error)
        loss = F.l1_loss(out, targets)
        # Zwraca stratę do backward() i optimizer.step()
        return loss
        
    def validation_step(self, batch):
        inputs, targets = batch
        out = self(inputs)
        loss = F.l1_loss(out, targets)
        # .detach() = odłącza tensor od grafu obliczeniowego (bez grad)
        return {'val_loss': loss.detach()}

    def validation_epoch_end(self, outputs):
        batch_losses = [x['val_loss'] for x in outputs]
        epoch_loss = torch.stack(batch_losses).mean()
        return {'val_loss': epoch_loss.item()}

    def epoch_end(self, epoch, result, num_epoch):
        # Drukuje tylko co 20 epok albo na końcu
        if (epoch+1) % 20 == 0 or epoch == num_epoch -1:
            print(f"Epoch [{epoch+1}], val_loss: {result['val_loss']}")

# %%
model = CarsModel()

list(model.parameters())
# Out:
# [Parameter containing:
#  tensor([[ 0.1787,  0.1606, -0.2684,  0.1624]], requires_grad=True),
#  Parameter containing:
#  tensor([-0.1004], requires_grad=True)]

# %% [markdown]
# <a id="creating-model"></a>
# # <a id='toc10_'></a>[<b><span style='color:darkorange'>Step 7.3 |</span><span style='color:#1E3A8A'> Training model</span></b>](#toc0_)

# %%
def evaluate(model, val_loader):
    outputs = [model.validation_step(batch) for batch in val_loader]
    return model.validation_epoch_end(outputs)

# Fitting algorithm
def fit(epochs, lr, model, train_loader, val_loader, opt_func=torch.optim.SGD):
    history = []
    optimizer = opt_func(model.parameters(), lr)
    for epoch in range(epochs):
        # Training Phase 
        for batch in train_loader:
            loss = model.training_step(batch)
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
        # Validation phase
        result = evaluate(model, val_loader)
        model.epoch_end(epoch, result, epochs)
        history.append(result)
    return history

# Check the initial value that val_loss have
result = evaluate(model, val_loader)
print(result)
# Out:
# {'val_loss': 9683.95703125}

# %%
# Start with the Fitting
epochs = 90
lr = 1e-8
history1 = fit(epochs, lr, model, train_loader, val_loader)
# Out:
# Epoch [20], val_loss: 8855.1650390625
# Epoch [40], val_loss: 8017.44140625
# Epoch [60], val_loss: 7180.794921875
# Epoch [80], val_loss: 6347.41796875
# Epoch [90], val_loss: 5943.32373046875

# %% [markdown]
# <a id="creating-model"></a>
# # <a id='toc10_'></a>[<b><span style='color:darkorange'>Step 7.4 |</span><span style='color:#1E3A8A'> Prediction</span></b>](#toc0_)

# %%
def predict(input, target, model):
    inputs = input.unsqueeze(0)
    prediction = model(inputs)
    prediction = prediction[0].detach()
    print("Input:", input)
    print("Target:", target)
    print("Prediction:", prediction)

input, target = val_ds[0]
predict(input, target, model)
# Out:
# Input: tensor([2.0060e+03, 4.1500e+00, 6.5000e+04, 0.0000e+00])
# Target: tensor([1.0500])
# Prediction: tensor([-10576.3115])

# %%
input, target = val_ds[10]
predict(input, target, model)
# Out:
# Input: tensor([2.0160e+03, 8.4000e-01, 2.5000e+04, 0.0000e+00])
# Target: tensor([0.6000])
# Prediction: tensor([-3839.1548])
